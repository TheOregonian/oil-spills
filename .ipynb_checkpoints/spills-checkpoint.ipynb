# %%
import pandas as pd;
import xlrd;
import math;
import numpy as np;
import re;
import geopandas;
pd.set_option('display.max_colwidth', -1)

# %%
print("Fetching Excel file.")
url = "http://nrc.uscg.mil/FOIAFiles/Current.xlsx"
try:
	xl = pd.ExcelFile(url)
except:
	print("Failed to fetch Excel file.")
# Out:
# Fetching Excel file.

# %%
print("Parsing Excel file.")
# Parse out sheets into separate DataFrames
calls = xl.parse("CALLS", na_values='');
incidents = pd.read_excel(url,"INCIDENTS",dtype={'PIER_DOCK_NUMBER':str})
incident_commons = xl.parse("INCIDENT_COMMONS");
incident_details = xl.parse("INCIDENT_DETAILS");
materials = xl.parse("MATERIAL_INVOLVED");
material_cr = xl.parse("MATERIAL_INV0LVED_CR");
trains = xl.parse("TRAINS_DETAIL");
traincars = xl.parse("DERAILED_UNITS");
vessels = xl.parse("VESSELS_DETAIL");
vehicles = xl.parse("MOBILE_DETAILS");
# Out:
# Parsing Excel file.

# %%
# Create a pretty date string for use in naming files later
import datetime
now = datetime.datetime.now()
now = now.strftime("%Y-%m-%d")

# Assemble all one-to-one tables into one big table
incident_commons = pd.merge(incident_commons,calls, on='SEQNOS')
incident_commons = pd.merge(incident_commons,incidents, on='SEQNOS')
incident_commons = pd.merge(incident_commons,incident_details, on='SEQNOS')

# %%
# Pull up our file showing the ID of the last record processed in the "Current.xls" file
# The file just keeps getting bigger every Sunday until calendar year end.
# --------------------------------------------------------------------------
# NOTE!!!!! If you are running this the first time, you want to delete the file
# called "bookmark" from your folder
# --------------------------------------------------------------------------

import os
exists = os.path.isfile('bookmark')
if exists:
    bookmark = pd.read_csv("bookmark")
    appending = True
else:
    appending = False

if appending:
	# Drop all the old records that we've already processed
	incident_commons = incident_commons[incident_commons.SEQNOS > int(bookmark.top[0])]
	materials = materials[materials.SEQNOS > int(bookmark.top[0])]
	material_cr = material_cr[material_cr.SEQNOS > int(bookmark.top[0])]
	trains = trains[trains.SEQNOS > int(bookmark.top[0])]
	traincars = traincars[traincars.SEQNOS > int(bookmark.top[0])]
	vessels = vessels[vessels.SEQNOS > int(bookmark.top[0])]
	vehicles = vehicles[vehicles.SEQNOS > int(bookmark.top[0])]

print("Writing out files.")

# Export many-to-one tables as separate files for import
materials.to_csv('materials' + now + '.csv')
material_cr.to_csv('material_cr' + now + '.csv')
trains.to_csv('trains' + now + '.csv')
traincars.to_csv('traincars' + now + '.csv')
vessels.to_csv('vessels' + now + '.csv')
vehicles.to_csv('vehicles' + now + '.csv')
# Out:
# Writing out files.

# %%
print("Processing coordinates.")

# Use full coordinates if available
incident_commons['new_latitude']  = incident_commons.LAT_DEG + (incident_commons.LAT_MIN / 60) + (incident_commons.LAT_SEC / 3600)
incident_commons['new_longitude'] = incident_commons.LONG_DEG + (incident_commons.LONG_MIN / 60) + (incident_commons.LONG_SEC / 3600)
incident_commons['new_latquad']   = incident_commons.LAT_QUAD
incident_commons['new_longquad']  = incident_commons.LONG_QUAD

# Basic coordinate cleaning function, from string to float
def splitclean(latitude):
    if isinstance(latitude,float):
        latitude = str(latitude)
    # Clear out extraneous characters
    latitude = re.sub(r'[A-Za-z]|\/|\'|\"|\&|\:|[\x00-\x1F\x80-\xFF]','',latitude)
    latitude = re.sub(r'\-',' ',latitude)
    latitude = re.sub(r' {2,}',' ',latitude)
    latitude = re.sub(r'\\p{C}','',latitude)
    latitude = re.sub(r'([0-9]{1,2}) (\..*)',r'\1' + r'\2',latitude)
    latitude = latitude.strip()
    # Break the string into components likely to be degrees, minutes and seconds
    components= latitude.split(' ')
    degrees = float; minutes = float; seconds = float;
    for i in range(len(components)):
        # No double decimal; ignore any digits after the second one
        components[i] = re.sub(r'\..*(\..*)',r'\0',components[i])
        # No leading and trailing zeroes
        components[i] = components[i].strip('0')
        # Only numeric characters and decimal points
        components[i] = re.sub(r'[^0-9.]+','',components[i])
        # No leading and trailing spaces
        components[i] = components[i].strip()
        # No leading and trailing decimal points
        components[i] = components[i].strip('.')
        if i < 2: # Weird case of single number with multiple decimal points
            components[i] = re.sub(r'\..*(\..*)',r'\0',components[i])
    if not components[0]:
        return # Skip if empty
    # Calculate degrees and minutes and compile into a single decimal unit
    else:
        degrees = float(components[0])
    if len(components) > 1:
        if isinstance(components[1],float):
        	minutes = float(components[1]) / 60
        	if len(components) == 3:
        		seconds = float(components[2]) / 3600
        		minutes = minutes + seconds
        	if degrees > 0:
        		degrees = degrees + minutes
        	else:
        		degrees = degrees - minutes
    return degrees
# Out:
# Processing coordinates.

# %%
####################################
# Latitude from INCIDENT_LOCATION
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\/| ).*:(.*),')[1].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude = incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\/| ).*:(.*)(N|S),')[1]
latquad  = incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\/| ).*:(.*)(N|S),')[2]

# Clean the latitude
latitude = latitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad

####################################
# Longitude from INCIDENT_LOCATION
####################################

# Find existing substring to parse for degrees, hours, minutes
longitude = incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\/| ).*:(.*)(N|S), (.*?)(W|E)')[3]
longquad  = incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\/| ).*:(.*)(N|S), (.*?)(W|E)')[4]
    
# Clean the longitude
longitude = longitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

# %%
####################################
# Latitude and longitude from INCIDENT_LOCATION using pattern of comma split
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.INCIDENT_LOCATION.str.extract(r'^([0-9].*),(.*)')[0].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude  = incident_commons.INCIDENT_LOCATION.str.extract(r'^([0-9].*),(.*)')[0]
longitude = incident_commons.INCIDENT_LOCATION.str.extract(r'^([0-9].*),(.*)')[1]
latquad   = latitude.str.extract(r'(N|S)')[0]
longquad  = longitude.str.extract(r'(W|E)')[0]

latitude  = latitude.apply(splitclean)
longitude = longitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad
incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

# %%
####################################
# LATITUDE FROM LOCATION_ADDRESS
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.INCIDENT_LOCATION.str.extract(r'^LAT(\:| |\.)(.*)')[1].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude = incident_commons.LOCATION_ADDRESS.str.extract(r'^LAT(\:| |\.)(.*)')[1]
latquad  = latitude.str.extract(r'(N|S)')[0]

latitude  = latitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad

####################################
# LONGITUDE FROM LOCATION_ADDRESS
####################################

# Find existing substring to parse for degrees, hours, minutes
longitude = incident_commons.LOCATION_STREET1.str.extract(r'^LONG(\:| |\.)(.*)')[1]
longquad  = longitude.str.extract(r'(E|W)')

longitude  = latitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

####################################
# Latitude and longitude from LOCATION_ADDRESS using pattern of comma split
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.LOCATION_ADDRESS.str.extract(r'^([0-9].*),(.*)')[0].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude  = incident_commons.LOCATION_ADDRESS.str.extract(r'^([0-9].*),(.*)')[0]
longitude = incident_commons.LOCATION_ADDRESS.str.extract(r'^([0-9].*),(.*)')[1]
latquad   = latitude.str.extract(r'(N|S)')[0]
longquad  = longitude.str.extract(r'(W|E)')[0]

latitude  = latitude.apply(splitclean)
longitude = longitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad
incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

# %%
####################################
# LATITUDE FROM LOCATION_STREET1
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.LOCATION_STREET1.str.extract(r'^LAT(\:| |\.)(.*)')[1].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude = incident_commons.LOCATION_STREET1.str.extract(r'^LAT(\:| |\.)(.*)')[1]
latquad  = latitude.str.extract(r'(N|S)')[0]

latitude  = latitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad

####################################
# LONGITUDE FROM LOCATION_STREET1
####################################

# Find existing substring to parse for degrees, hours, minutes
longitude = incident_commons.LOCATION_STREET2.str.extract(r'^LONG(\:| |\.)(.*)')[1]
longquad  = longitude.str.extract(r'(E|W)')

longitude  = latitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

####################################
# Latitude and longitude from LOCATION_STREET1 using pattern of comma split
####################################

# Start with boolean expression to operate on
null_latitude = (incident_commons.new_latitude.isnull()) & (incident_commons.LOCATION_STREET1.str.extract(r'^([0-9].*),(.*)')[0].notnull())

# Find existing substring to parse for degrees, hours, minutes
latitude  = incident_commons.LOCATION_STREET1.str.extract(r'^([0-9].*),(.*)')[0]
longitude = incident_commons.LOCATION_STREET1.str.extract(r'^([0-9].*),(.*)')[1]
latquad   = latitude.str.extract(r'(N|S)')[0]
longquad  = longitude.str.extract(r'(W|E)')[0]

latitude  = latitude.apply(splitclean)
longitude = longitude.apply(splitclean)

incident_commons.loc[null_latitude,'new_latitude'] = latitude
incident_commons.loc[null_latitude,'new_latquad']  = latquad
incident_commons.loc[null_latitude,'new_longitude'] = longitude
incident_commons.loc[null_latitude,'new_longquad']  = longquad

# %%
# Function for testing if column contains a street
def findstreet(location):
    if isinstance(location,float):
        return False
    elif location == '':
        return False
    else:
        location = location.encode('utf-8')
        location = str(location)
        location = re.sub(r'\\p{C}|[\x00-\x1F\x80-\xFF]','',location)
        if re.search(r' (RD|ROAD|AVE|AVENUE|LN|LANE|PL|PLACE|HWY|HIGHWAY|BLVD|BOULEVARD|CT|COURT|CIR|CIRCLE|ROUTE|RTE|WY|WAY)( |\.|$)',location):
            return True
    return False

# Boolean for selecting records with street
has_street = incident_commons.LOCATION_ADDRESS.apply(findstreet) == True
incident_commons['new_street'] = ''
incident_commons['new_street'] = np.nan
# Apply address if exists in loc address
incident_commons.loc[has_street,'new_street'] = incident_commons.LOCATION_ADDRESS
has_street = (incident_commons.LOCATION_STREET1.apply(findstreet) == True) & (incident_commons.new_street.isnull())
# Apply address if exists in street1
incident_commons.loc[has_street,'new_street'] = incident_commons.LOCATION_STREET1
# Apply address if exists in incident location
has_street = (incident_commons.INCIDENT_LOCATION.apply(findstreet) == True) & (incident_commons.new_street.isnull())
incident_commons.loc[has_street,'new_street'] = incident_commons.INCIDENT_LOCATION

# %%
print("Starting geocoder.")
# Create geodataframe for geocoding
geo = geopandas.GeoDataFrame(incident_commons)
counter = 0
from geopy.geocoders import Bing

def get_apikey(servicename):
    import pandas as pd
    import os
    if os.path.isfile('/etc/apikeys'):
        path = '/etc/apikeys'
    else:
        if os.path.isfile('apikeys'):
            path = 'apikeys'
        else:
            return False
    keyfile = pd.read_csv(path)
    keydict = keyfile.to_dict('records')
    for row in keydict:
        if row['service'] == servicename:
            apikey = row['key']
            return apikey

# bingkey = get_apikey('bing')
# if bingkey == False:
#     print "Could not find necessary API key file."
#     quit()

bingkey = "AuNPKK6wEhtJOp2JSz1iQQwqgCptimUiyamkP18Bnz4ycjMaxcFdd1kYEqyWrdxL"
# Out:
# Starting geocoder.

# %%
# Compile an address string for submission to geocoder, then submit request

for row in geo.itertuples():
    counter+=1
    print(counter)
    # Skip this record for geocoding if latitude is already populated
    if not math.isnan(row.new_latitude):
        print("Latitude already there.")
        continue
    # Compile the address using available street/city/county/state fields
    print("Compiling address")
    address = ''
    if not isinstance(row.LOCATION_STATE,float):
        address = str(row.LOCATION_STATE)
    if not isinstance(row.LOCATION_NEAREST_CITY,float):
        address = str(row.LOCATION_NEAREST_CITY) + ',' + address
    else:
        if not isinstance(row.LOCATION_COUNTY,float):
            address = str(row.LOCATION_COUNTY) + ' COUNTY,' + address
    if not isinstance(row.new_street,float):
        address = str(row.new_street) + ',' + address
    if address == '':
        if not isinstance(row.INCIDENT_LOCATION,float):
            address = str(row.INCIDENT_LOCATION,float)
        else:
            continue
    print(str(counter) + ' ' + address)
    # Geocode the address
    try:
        location = geopandas.tools.geocode(address,provider="Bing",api_key=bingkey)
        location['SEQNOS'] = row.SEQNOS
        if counter == 1:
            locations = geopandas.GeoDataFrame(location)
        else:
            locations = locations.append(location)
        print("Geocoded one address.")
        print(location)
    except:
        print("Geocoder failed.")
        continue

    if counter > 10:
        break
# Out:
# 1
# Compiling address
# 1 SPARTANBURG,SC
# Geocoder failed.
# 2
# Compiling address
# 2 SPARTANBURG,SC
# Geocoder failed.
# 3
# Compiling address
# 3 3235 16TH AVE SW,SEATTLE,WA
# Geocoder failed.
# 4
# Compiling address
# 4 3235 16TH AVE SW,SEATTLE,WA
# Geocoder failed.
# 5
# Latitude already there.
# 6
# Latitude already there.
# 7
# Compiling address
# 7 IOLA,KS
# Geocoder failed.
# 8
# Compiling address
# 8 IOLA,KS
# Geocoder failed.
# 9
# Compiling address
# 9 LAPORTE,TX
# Geocoder failed.
# 10
# Compiling address
# 10 LAPORTE,TX
# Geocoder failed.
# 11
# Latitude already there.
# 12
# Latitude already there.
# 13
# Compiling address
# 13 GRANITE FALLS,NC
# Geocoder failed.
# 14
# Compiling address
# 14 GRANITE FALLS,NC
# Geocoder failed.
# 15
# Compiling address
# 15 EUGENE,OR
# Geocoder failed.
# 16
# Compiling address
# 16 EUGENE,OR
# Geocoder failed.
# 17
# Latitude already there.
# 18
# Latitude already there.
# 19
# Compiling address
# 19 TOLEDO,OR
# Geocoder failed.
# 20
# Compiling address
# 20 TOLEDO,OR
# Geocoder failed.
# 21
# Compiling address
# 21 AKRON,OH
# Geocoder failed.
# 22
# Compiling address
# 22 AKRON,OH
# Geocoder failed.
# 23
# Latitude already there.
# 24
# Latitude already there.
# 25
# Latitude already there.
# 26
# Latitude already there.
# 27
# Latitude already there.
# 28
# Latitude already there.
# 29
# Compiling address
# 29 QUEENS,NY
# Geocoder failed.
# 30
# Compiling address
# 30 QUEENS,NY
# Geocoder failed.
# 31
# Compiling address
# 31 POMPANO BEACH,FL
# Geocoder failed.
# 32
# Compiling address
# 32 POMPANO BEACH,FL
# Geocoder failed.
# 33
# Latitude already there.
# 34
# Latitude already there.
# 35
# Compiling address
# 35 15551 HWY 23 SOUTH,BELLE CHASSE,LA
# Geocoder failed.
# 36
# Compiling address
# 36 15551 HWY 23 SOUTH,BELLE CHASSE,LA
# Geocoder failed.
# 37
# Compiling address
# 37 LOA,UT
# Geocoder failed.
# 38
# Compiling address
# 38 LOA,UT
# Geocoder failed.
# 39
# Compiling address
# 39 CARTERSVILLE,GA
# Geocoder failed.
# 40
# Compiling address
# 40 CARTERSVILLE,GA
# Geocoder failed.
# 41
# Compiling address
# 41 BOSTON,MA
# Geocoder failed.
# 42
# Compiling address
# 42 BOSTON,MA
# Geocoder failed.
# 43
# Latitude already there.
# 44
# Latitude already there.
# 45
# Compiling address
# 45 MIDDLETOWN,CA
# Geocoder failed.
# 46
# Compiling address
# 46 MIDDLETOWN,CA
# Geocoder failed.
# 47
# Compiling address
# 47 2ND AVE NW & NW 100TH ST,SEATTLE,WA
# Geocoder failed.
# 48
# Compiling address
# 48 2ND AVE NW & NW 100TH ST,SEATTLE,WA
# Geocoder failed.
# 49
# Compiling address
# 49 GRANDVIEW,WA
# Geocoder failed.
# 50
# Compiling address
# 50 GRANDVIEW,WA
# Geocoder failed.
# 51
# Compiling address
# 51 COLUMBUS,OH
# Geocoder failed.
# 52
# Compiling address
# 52 COLUMBUS,OH
# Geocoder failed.
# 53
# Compiling address
# 53 ELKO,NV
# Geocoder failed.
# 54
# Compiling address
# 54 ELKO,NV
# Geocoder failed.
# 55
# Compiling address
# 55 KATKA,ID
# Geocoder failed.
# 56
# Compiling address
# 56 KATKA,ID
# Geocoder failed.
# 57
# Compiling address
# 57 BIRMINGHAM,AL
# Geocoder failed.
# 58
# Compiling address
# 58 BIRMINGHAM,AL
# Geocoder failed.
# 59
# Compiling address
# 59 FLAGSTAFF,AZ
# Geocoder failed.
# 60
# Compiling address
# 60 FLAGSTAFF,AZ
# Geocoder failed.
# 61
# Compiling address
# 61 BETHLEHEM,PA
# Geocoder failed.
# 62
# Compiling address
# 62 BETHLEHEM,PA
# Geocoder failed.
# 63
# Compiling address
# 63 SAN DIEGO,CA
# Geocoder failed.
# 64
# Compiling address
# 64 SAN DIEGO,CA
# Geocoder failed.
# 65
# Compiling address
# 65 ASHLAND,VA
# Geocoder failed.
# 66
# Compiling address
# 66 ASHLAND,VA
# Geocoder failed.
# 67
# Compiling address
# 67 SAN DIEGO,CA
# Geocoder failed.
# 68
# Compiling address
# 68 SAN DIEGO,CA
# Geocoder failed.
# 69
# Compiling address
# 69 PASCAGOULA,MS
# Geocoder failed.
# 70
# Compiling address
# 70 PASCAGOULA,MS
# Geocoder failed.
# 71
# Compiling address
# 71 CONGO,MO
# Geocoder failed.
# 72
# Compiling address
# 72 CONGO,MO
# Geocoder failed.
# 73
# Compiling address
# 73 GRAND RAPIDS,MI
# Geocoder failed.
# 74
# Compiling address
# 74 GRAND RAPIDS,MI
# Geocoder failed.
# 75
# Compiling address
# 75 CANTONMENT,FL
# Geocoder failed.
# 76
# Compiling address
# 76 CANTONMENT,FL
# Geocoder failed.
# 77
# Compiling address
# 77 DURHAM,NC
# Geocoder failed.
# 78
# Compiling address
# 78 DURHAM,NC
# Geocoder failed.
# 79
# Compiling address
# 79 MARGE COURT AND OLD FORT RD,FORT WASHINGTON,MD
# Geocoder failed.
# 80
# Compiling address
# 80 MARGE COURT AND OLD FORT RD,FORT WASHINGTON,MD
# Geocoder failed.
# 81
# Latitude already there.
# 82
# Latitude already there.
# 83
# Compiling address
# 83 EL DORADO,KS
# Geocoder failed.
# 84
# Compiling address
# 84 EL DORADO,KS
# Geocoder failed.
# 85
# Latitude already there.
# 86
# Latitude already there.
# 87
# Compiling address
# 87 KODAK,TN
# Geocoder failed.
# 88
# Compiling address
# 88 KODAK,TN
# Geocoder failed.
# 89
# Compiling address
# 89 COLUMBUS,OH
# Geocoder failed.
# 90
# Compiling address
# 90 COLUMBUS,OH
# Geocoder failed.
# 91
# Compiling address
# 91 NORFOLK,VA
# Geocoder failed.
# 92
# Compiling address
# 92 NORFOLK,VA
# Geocoder failed.
# 93
# Compiling address
# 93 COLUMBUS,OH
# Geocoder failed.
# 94
# Compiling address
# 94 COLUMBUS,OH
# Geocoder failed.
# 95
# Compiling address
# 95 THEODORE,AL
# Geocoder failed.
# 96
# Compiling address
# 96 THEODORE,AL
# Geocoder failed.
# 97
# Compiling address
# 97 CAPE CANAVERAL,FL
# Geocoder failed.
# 98
# Compiling address
# 98 CAPE CANAVERAL,FL
# Geocoder failed.
# 99
# Compiling address
# 99 PITTSFIELD,MA
# Geocoder failed.
# 100
# Compiling address
# 100 PITTSFIELD,MA
# Geocoder failed.
# 101
# Compiling address
# 101 REHOBOTH,MA
# Geocoder failed.
# 102
# Compiling address
# 102 REHOBOTH,MA
# Geocoder failed.
# 103
# Latitude already there.
# 104
# Latitude already there.
# 105
# Latitude already there.
# 106
# Latitude already there.
# 107
# Compiling address
# 107 FORT MYERS BEACH,FL
# Geocoder failed.
# 108
# Compiling address
# 108 FORT MYERS BEACH,FL
# Geocoder failed.
# 109
# Compiling address
# 109 2401 PGA BLVD.,WEST PALM BEACH,FL
# Geocoder failed.
# 110
# Compiling address
# 110 2401 PGA BLVD.,WEST PALM BEACH,FL
# Geocoder failed.
# 111
# Compiling address
# 111 STUART,FL
# Geocoder failed.
# 112
# Compiling address
# 112 STUART,FL
# Geocoder failed.
# 113
# Compiling address
# 113 WYNCOTE,PA
# Geocoder failed.
# 114
# Compiling address
# 114 WYNCOTE,PA
# Geocoder failed.
# 115
# Compiling address
# 115 LE GRAND,CA
# Geocoder failed.
# 116
# Compiling address
# 116 LE GRAND,CA
# Geocoder failed.
# 117
# Compiling address
# 117 HOUMA,LA
# Geocoder failed.
# 118
# Compiling address
# 118 HOUMA,LA
# Geocoder failed.
# 119
# Compiling address
# 119 FORT PIERCE,FL
# Geocoder failed.
# 120
# Compiling address
# 120 FORT PIERCE,FL
# Geocoder failed.
# 121
# Compiling address
# 121 JACKSONVILLE,FL
# Geocoder failed.
# 122
# Compiling address
# 122 JACKSONVILLE,FL
# Geocoder failed.
# 123
# Compiling address
# 123 SUGAR CREEK,MO
# Geocoder failed.
# 124
# Compiling address
# 124 SUGAR CREEK,MO
# Geocoder failed.
# 125
# Compiling address
# 125 CLEVELAND COUNTY,NC
# Geocoder failed.
# 126
# Compiling address
# 126 CLEVELAND COUNTY,NC
# Geocoder failed.
# 127
# Compiling address
# 127 JACKSONVILLE,FL
# Geocoder failed.
# 128
# Compiling address
# 128 JACKSONVILLE,FL
# Geocoder failed.
# 129
# Compiling address
# 129 THORNTON,CO
# Geocoder failed.
# 130
# Compiling address
# 130 THORNTON,CO
# Geocoder failed.
# 131
# Compiling address
# 131 STURGEON BAY,WI
# Geocoder failed.
# 132
# Compiling address
# 132 STURGEON BAY,WI
# Geocoder failed.
# 133
# Latitude already there.
# 134
# Latitude already there.
# 135
# Compiling address
# 135 NEW ORLEANS,LA
# Geocoder failed.
# 136
# Compiling address
# 136 NEW ORLEANS,LA
# Geocoder failed.
# 137
# Compiling address
# 137 CLARKS SUMMIT,PA
# Geocoder failed.
# 138
# Compiling address
# 138 CLARKS SUMMIT,PA
# Geocoder failed.
# 139
# Compiling address
# 139 MARGATE,FL
# Geocoder failed.
# 140
# Compiling address
# 140 MARGATE,FL
# Geocoder failed.
# 141
# Compiling address
# 141 NORFOLK,VA
# Geocoder failed.
# 142
# Compiling address
# 142 NORFOLK,VA
# Geocoder failed.
# 143
# Compiling address
# 143 GENEVA,NE
# Geocoder failed.
# 144
# Compiling address
# 144 GENEVA,NE
# Geocoder failed.
# 145
# Compiling address
# 145 GALVESTON,TX
# Geocoder failed.
# 146
# Compiling address
# 146 GALVESTON,TX
# Geocoder failed.
# 147
# Compiling address
# 147 STEEL CREEK - BETWEEN CAROLINES BLVD AND HWY. 49,CHARLOTTE,NC
# Geocoder failed.
# 148
# Compiling address
# 148 STEEL CREEK - BETWEEN CAROLINES BLVD AND HWY. 49,CHARLOTTE,NC
# Geocoder failed.
# 149
# Compiling address
# 149 PALMETTO,FL
# Geocoder failed.
# 150
# Compiling address
# 150 PALMETTO,FL
# Geocoder failed.
# 151
# Compiling address
# 151 MUSKEGON HEIGHTS,MI
# Geocoder failed.
# 152
# Compiling address
# 152 MUSKEGON HEIGHTS,MI
# Geocoder failed.
# 153
# Compiling address
# 153 NAPOLEON,OH
# Geocoder failed.
# 154
# Compiling address
# 154 NAPOLEON,OH
# Geocoder failed.
# 155
# Compiling address
# 155 FORT HARRISON,MT
# Geocoder failed.
# 156
# Compiling address
# 156 FORT HARRISON,MT
# Geocoder failed.
# 157
# Latitude already there.
# 158
# Latitude already there.
# 159
# Compiling address
# 159 90 INDUSTRIAL ROAD WEST,MOBILE,AL
# Geocoder failed.
# 160
# Compiling address
# 160 90 INDUSTRIAL ROAD WEST,MOBILE,AL
# Geocoder failed.
# 161
# Compiling address
# 161 NEWARK,NJ
# Geocoder failed.
# 162
# Compiling address
# 162 NEWARK,NJ
# Geocoder failed.
# 163
# Compiling address
# 163 MOBILE,AL
# Geocoder failed.
# 164
# Compiling address
# 164 MOBILE,AL
# Geocoder failed.
# 165
# Compiling address
# 165 APOLLO BEACH,FL
# Geocoder failed.
# 166
# Compiling address
# 166 APOLLO BEACH,FL
# Geocoder failed.
# 167
# Compiling address
# 167 CORPUS CHRISTI,TX
# Geocoder failed.
# 168
# Compiling address
# 168 CORPUS CHRISTI,TX
# Geocoder failed.
# 169
# Compiling address
# 169 MIAMI RIVER BETWEEN S MIAMI AVE AND 2ND AVENUE BRIDGE,MIAMI,FL
# Geocoder failed.
# 170
# Compiling address
# 170 MIAMI RIVER BETWEEN S MIAMI AVE AND 2ND AVENUE BRIDGE,MIAMI,FL
# Geocoder failed.
# 171
# Compiling address
# 171 PORTLAND,OR
# Geocoder failed.
# 172
# Compiling address
# 172 PORTLAND,OR
# Geocoder failed.
# 173
# Latitude already there.
# 174
# Latitude already there.
# 175
# Compiling address
# 175 THE DALLES,OR
# Geocoder failed.
# 176
# Compiling address
# 176 THE DALLES,OR
# Geocoder failed.
# 177
# Compiling address
# 177 CLIFTON FORGE,VA
# Geocoder failed.
# 178
# Compiling address
# 178 CLIFTON FORGE,VA
# Geocoder failed.
# 179
# Compiling address
# 179 LAREDO,TX
# Geocoder failed.
# 180
# Compiling address
# 180 LAREDO,TX
# Geocoder failed.
# 181
# Compiling address
# 181 PORTLAND,OR
# Geocoder failed.
# 182
# Compiling address
# 182 PORTLAND,OR
# Geocoder failed.
# 183
# Compiling address
# 183 2815 INDIANAPOLIS BLVD.,WHITING,IN
# Geocoder failed.
# 184
# Compiling address
# 184 2815 INDIANAPOLIS BLVD.,WHITING,IN
# Geocoder failed.
# 185
# Compiling address
# 185 PORTLAND,OR
# Geocoder failed.
# 186
# Compiling address
# 186 PORTLAND,OR
# Geocoder failed.
# 187
# Compiling address
# 187 HONOLULU,HI
# Geocoder failed.
# 188
# Compiling address
# 188 HONOLULU,HI
# Geocoder failed.
# 189
# Compiling address
# 189 MIDDLETOWN,CA
# Geocoder failed.
# 190
# Compiling address
# 190 MIDDLETOWN,CA
# Geocoder failed.
# 191
# Compiling address
# 191 SAN CLEMENTE,CA
# Geocoder failed.
# 192
# Compiling address
# 192 SAN CLEMENTE,CA
# Geocoder failed.
# 193
# Compiling address
# 193 DANA POINT,CA
# Geocoder failed.
# 194
# Compiling address
# 194 DANA POINT,CA
# Geocoder failed.
# 195
# Compiling address
# 195 CARLSBAD,NM
# Geocoder failed.
# 196
# Compiling address
# 196 CARLSBAD,NM
# Geocoder failed.
# 197
# Compiling address
# 197 OLYMPIA,WA
# Geocoder failed.
# 198
# Compiling address
# 198 OLYMPIA,WA
# Geocoder failed.
# 199
# Compiling address
# 199 38003 FARM ROAD 1379,MIDLAND,TX
# Geocoder failed.
# 200
# Compiling address
# 200 38003 FARM ROAD 1379,MIDLAND,TX
# Geocoder failed.
# 201
# Compiling address
# 201 DEER PARK,TX
# Geocoder failed.
# 202
# Compiling address
# 202 DEER PARK,TX
# Geocoder failed.
# 203
# Compiling address
# 203 HAPEVILLE,GA
# Geocoder failed.
# 204
# Compiling address
# 204 HAPEVILLE,GA
# Geocoder failed.
# 205
# Compiling address
# 205 280 GROVE RD.,KEMAH,TX
# Geocoder failed.
# 206
# Compiling address
# 206 280 GROVE RD.,KEMAH,TX
# Geocoder failed.
# 207
# Compiling address
# 207 VICKSBURG,MS
# Geocoder failed.
# 208
# Compiling address
# 208 VICKSBURG,MS
# Geocoder failed.
# 209
# Compiling address
# 209 PATCHOGUE,NY
# Geocoder failed.
# 210
# Compiling address
# 210 PATCHOGUE,NY
# Geocoder failed.
# 211
# Compiling address
# 211 BAYONNE,NJ
# Geocoder failed.
# 212
# Compiling address
# 212 BAYONNE,NJ
# Geocoder failed.
# 213
# Compiling address
# 213 WHITESTONE,NY
# Geocoder failed.
# 214
# Compiling address
# 214 WHITESTONE,NY
# Geocoder failed.
# 215
# Compiling address
# 215 MIDDLESEX,NJ
# Geocoder failed.
# 216
# Compiling address
# 216 MIDDLESEX,NJ
# Geocoder failed.
# 217
# Compiling address
# 217 SAINT PETERSBURG,FL
# Geocoder failed.
# 218
# Compiling address
# 218 SAINT PETERSBURG,FL
# Geocoder failed.
# 219
# Compiling address
# 219 WOOLWICH TWP,NJ
# Geocoder failed.
# 220
# Compiling address
# 220 WOOLWICH TWP,NJ
# Geocoder failed.
# 221
# Compiling address
# 221 ALEXANDRIA,LA
# Geocoder failed.
# 222
# Compiling address
# 222 ALEXANDRIA,LA
# Geocoder failed.
# 223
# Latitude already there.
# 224
# Latitude already there.
# 225
# Compiling address
# 225 EVERETT,MA
# Geocoder failed.
# 226
# Compiling address
# 226 EVERETT,MA
# Geocoder failed.
# 227
# Compiling address
# 227 FORT LAUDERDALE,FL
# Geocoder failed.
# 228
# Compiling address
# 228 FORT LAUDERDALE,FL
# Geocoder failed.
# 229
# Compiling address
# 229 DETROIT,MI
# Geocoder failed.
# 230
# Compiling address
# 230 DETROIT,MI
# Geocoder failed.
# 231
# Compiling address
# 231 GROTON,CT
# Geocoder failed.
# 232
# Compiling address
# 232 GROTON,CT
# Geocoder failed.
# 233
# Compiling address
# 233 LONGMONT,CO
# Geocoder failed.
# 234
# Compiling address
# 234 LONGMONT,CO
# Geocoder failed.
# 235
# Compiling address
# 235 HOLLIDAY,TX
# Geocoder failed.
# 236
# Compiling address
# 236 HOLLIDAY,TX
# Geocoder failed.
# 237
# Compiling address
# 237 FLOUR BLUFF,TX
# Geocoder failed.
# 238
# Compiling address
# 238 FLOUR BLUFF,TX
# Geocoder failed.
# 239
# Compiling address
# 239 4021 PARKMAN RD NW,WARREN,OH
# Geocoder failed.
# 240
# Compiling address
# 240 4021 PARKMAN RD NW,WARREN,OH
# Geocoder failed.
# 241
# Compiling address
# 241 SYRACUSE,NY
# Geocoder failed.
# 242
# Compiling address
# 242 SYRACUSE,NY
# Geocoder failed.
# 243
# Latitude already there.
# 244
# Latitude already there.
# 245
# Compiling address
# 245 BROOKLYN,NY
# Geocoder failed.
# 246
# Compiling address
# 246 BROOKLYN,NY
# Geocoder failed.
# 247
# Latitude already there.
# 248
# Latitude already there.
# 249
# Compiling address
# 249 ISLE OF PALMS,SC
# Geocoder failed.
# 250
# Compiling address
# 250 ISLE OF PALMS,SC
# Geocoder failed.
# 251
# Compiling address
# 251 VALLEY BLVD 1/2 MILE EAST OF DANNISON ROAD,TEHACHAPI,CA
# Geocoder failed.
# 252
# Compiling address
# 252 VALLEY BLVD 1/2 MILE EAST OF DANNISON ROAD,TEHACHAPI,CA
# Geocoder failed.
# 253
# Compiling address
# 253 TUMWATER,WA
# Geocoder failed.
# 254
# Compiling address
# 254 TUMWATER,WA
# Geocoder failed.
# 255
# Compiling address
# 255 3301 TRINDLE RD.,CAMP HILL,PA
# Geocoder failed.
# 256
# Compiling address
# 256 3301 TRINDLE RD.,CAMP HILL,PA
# Geocoder failed.
# 257
# Compiling address
# 257 LECLAIRE,IA
# Geocoder failed.
# 258
# Compiling address
# 258 LECLAIRE,IA
# Geocoder failed.
# 259
# Compiling address
# 259 NORTH LITTLE ROCK,AR
# Geocoder failed.
# 260
# Compiling address
# 260 NORTH LITTLE ROCK,AR
# Geocoder failed.
# 261
# Compiling address
# 261 CHANNELVIEW,TX
# Geocoder failed.
# 262
# Compiling address
# 262 CHANNELVIEW,TX
# Geocoder failed.
# 263
# Compiling address
# 263 UNKNOWN COUNTY,XX
# Geocoder failed.
# 264
# Compiling address
# 264 UNKNOWN COUNTY,XX
# Geocoder failed.
# 265
# Compiling address
# 265 BOSIER CITY,LA
# Geocoder failed.
# 266
# Compiling address
# 266 BOSIER CITY,LA
# Geocoder failed.
# 267
# Compiling address
# 267 INDUSTRY,PA
# Geocoder failed.
# 268
# Compiling address
# 268 INDUSTRY,PA
# Geocoder failed.
# 269
# Compiling address
# 269 THUNDERBOLT,GA
# Geocoder failed.
# 270
# Compiling address
# 270 THUNDERBOLT,GA
# Geocoder failed.
# 271
# Latitude already there.
# 272
# Latitude already there.
# 273
# Compiling address
# 273 US HWY 41 AND ALICO RD,FORT MYERS,FL
# Geocoder failed.
# 274
# Compiling address
# 274 US HWY 41 AND ALICO RD,FORT MYERS,FL
# Geocoder failed.
# 275
# Compiling address
# 275 RENO,NV
# Geocoder failed.
# 276
# Compiling address
# 276 RENO,NV
# Geocoder failed.
# 277
# Compiling address
# 277 MARCUS HOOK,PA
# Geocoder failed.
# 278
# Compiling address
# 278 MARCUS HOOK,PA
# Geocoder failed.
# 279
# Compiling address
# 279 ZEELAND,MI
# Geocoder failed.
# 280
# Compiling address
# 280 ZEELAND,MI
# Geocoder failed.
# 281
# Compiling address
# 281 PORT ORCHARD,WA
# Geocoder failed.
# 282
# Compiling address
# 282 PORT ORCHARD,WA
# Geocoder failed.
# 283
# Compiling address
# 283 DETRIOT,MI
# Geocoder failed.
# 284
# Compiling address
# 284 DETRIOT,MI
# Geocoder failed.
# 285
# Compiling address
# 285 PIKEVILLE,KY
# Geocoder failed.
# 286
# Compiling address
# 286 PIKEVILLE,KY
# Geocoder failed.
# 287
# Compiling address
# 287 3800 CORKSCREW RD.,ESTERO,FL
# Geocoder failed.
# 288
# Compiling address
# 288 3800 CORKSCREW RD.,ESTERO,FL
# Geocoder failed.
# 289
# Latitude already there.
# 290
# Latitude already there.
# 291
# Compiling address
# 291 STERLING,MA
# Geocoder failed.
# 292
# Compiling address
# 292 STERLING,MA
# Geocoder failed.
# 293
# Compiling address
# 293 SAN DIEGO,CA
# Geocoder failed.
# 294
# Compiling address
# 294 SAN DIEGO,CA
# Geocoder failed.
# 295
# Compiling address
# 295 EL PASO,TX
# Geocoder failed.
# 296
# Compiling address
# 296 EL PASO,TX
# Geocoder failed.
# 297
# Compiling address
# 297 NANTICOKE,MD
# Geocoder failed.
# 298
# Compiling address
# 298 NANTICOKE,MD
# Geocoder failed.
# 299
# Compiling address
# 299 LECLAIRE,IA
# Geocoder failed.
# 300
# Compiling address
# 300 LECLAIRE,IA
# Geocoder failed.
# 301
# Compiling address
# 301 FT MYERS,FL
# Geocoder failed.
# 302
# Compiling address
# 302 FT MYERS,FL
# Geocoder failed.
# 303
# Compiling address
# 303 MOSSLANDING,CA
# Geocoder failed.
# 304
# Compiling address
# 304 MOSSLANDING,CA
# Geocoder failed.
# 305
# Compiling address
# 305 ALEXANDRIA,VA
# Geocoder failed.
# 306
# Compiling address
# 306 ALEXANDRIA,VA
# Geocoder failed.
# 307
# Compiling address
# 307 BELTSVILLE,MD
# Geocoder failed.
# 308
# Compiling address
# 308 BELTSVILLE,MD
# Geocoder failed.
# 309
# Compiling address
# 309 LECLAIRE,IA
# Geocoder failed.
# 310
# Compiling address
# 310 LECLAIRE,IA
# Geocoder failed.
# 311
# Compiling address
# 311 JUNEAU,AK
# Geocoder failed.
# 312
# Compiling address
# 312 JUNEAU,AK
# Geocoder failed.
# 313
# Compiling address
# 313 CHARLESTON,SC
# Geocoder failed.
# 314
# Compiling address
# 314 CHARLESTON,SC
# Geocoder failed.
# 315
# Compiling address
# 315 BOTHELL,WA
# Geocoder failed.
# 316
# Compiling address
# 316 BOTHELL,WA
# Geocoder failed.
# 317
# Compiling address
# 317 38125 2ND AVE S,ROY,WA
# Geocoder failed.
# 318
# Compiling address
# 318 38125 2ND AVE S,ROY,WA
# Geocoder failed.
# 319
# Compiling address
# 319 EAST STROUDBURG,PA
# Geocoder failed.
# 320
# Compiling address
# 320 EAST STROUDBURG,PA
# Geocoder failed.
# 321
# Compiling address
# 321 PEMBROKE,NC
# Geocoder failed.
# 322
# Compiling address
# 322 PEMBROKE,NC
# Geocoder failed.
# 323
# Compiling address
# 323 10 FORDING ISLAND ROAD EXTENSION,HILTON HEAD ISLAND,SC
# Geocoder failed.
# 324
# Compiling address
# 324 10 FORDING ISLAND ROAD EXTENSION,HILTON HEAD ISLAND,SC
# Geocoder failed.
# 325
# Latitude already there.
# 326
# Latitude already there.
# 327
# Compiling address
# 327 LOS GATOS,CA
# Geocoder failed.
# 328
# Compiling address
# 328 LOS GATOS,CA
# Geocoder failed.
# 329
# Compiling address
# 329 CALLER STATED THE SPILL STARTS AT 621 11 AVENUE EAST, IN ROUNDUP, MT,ROUNDUP,MT
# Geocoder failed.
# 330
# Compiling address
# 330 CALLER STATED THE SPILL STARTS AT 621 11 AVENUE EAST, IN ROUNDUP, MT,ROUNDUP,MT
# Geocoder failed.
# 331
# Compiling address
# 331 HOPEWELL,VA
# Geocoder failed.
# 332
# Compiling address
# 332 HOPEWELL,VA
# Geocoder failed.
# 333
# Latitude already there.
# 334
# Latitude already there.
# 335
# Compiling address
# 335 MACON,GA
# Geocoder failed.
# 336
# Compiling address
# 336 MACON,GA
# Geocoder failed.
# 337
# Latitude already there.
# 338
# Latitude already there.
# 339
# Compiling address
# 339 ANTIOCH,CA
# Geocoder failed.
# 340
# Compiling address
# 340 ANTIOCH,CA
# Geocoder failed.
# 341
# Compiling address
# 341 CAMDEN,NJ
# Geocoder failed.
# 342
# Compiling address
# 342 CAMDEN,NJ
# Geocoder failed.
# 343
# Compiling address
# 343 FORDHAM ROAD STATION,BRONX,NY
# Geocoder failed.
# 344
# Compiling address
# 344 FORDHAM ROAD STATION,BRONX,NY
# Geocoder failed.
# 345
# Compiling address
# 345 US HIGHWAY 82,TIFTON,GA
# Geocoder failed.
# 346
# Compiling address
# 346 US HIGHWAY 82,TIFTON,GA
# Geocoder failed.
# 347
# Compiling address
# 347 WICKLIFFE,KY
# Geocoder failed.
# 348
# Compiling address
# 348 WICKLIFFE,KY
# Geocoder failed.
# 349
# Compiling address
# 349 FURNACE AVE AND MARGATE DR,GLEN BURNIE,MD
# Geocoder failed.
# 350
# Compiling address
# 350 FURNACE AVE AND MARGATE DR,GLEN BURNIE,MD
# Geocoder failed.
# 351
# Latitude already there.
# 352
# Latitude already there.
# 353
# Compiling address
# 353 SANFORD,FL
# Geocoder failed.
# 354
# Compiling address
# 354 SANFORD,FL
# Geocoder failed.
# 355
# Compiling address
# 355 BEAUFORT/RADIO ISLAND,NC
# Geocoder failed.
# 356
# Compiling address
# 356 BEAUFORT/RADIO ISLAND,NC
# Geocoder failed.
# 357
# Latitude already there.
# 358
# Latitude already there.
# 359
# Compiling address
# 359 MIAMISBURG,OH
# Geocoder failed.
# 360
# Compiling address
# 360 MIAMISBURG,OH
# Geocoder failed.
# 361
# Compiling address
# 361 SUNNY ISLES BEACH,FL
# Geocoder failed.
# 362
# Compiling address
# 362 SUNNY ISLES BEACH,FL
# Geocoder failed.
# 363
# Compiling address
# 363 HOUSTON,TX
# Geocoder failed.
# 364
# Compiling address
# 364 HOUSTON,TX
# Geocoder failed.
# 365
# Compiling address
# 365 SUGAR CREEK,MO
# Geocoder failed.
# 366
# Compiling address
# 366 SUGAR CREEK,MO
# Geocoder failed.
# 367
# Compiling address
# 367 MONTE VISTA,CO
# Geocoder failed.
# 368
# Compiling address
# 368 MONTE VISTA,CO
# Geocoder failed.
# 369
# Compiling address
# 369 KING RD. WEST OF WESTFIELD,TRENTON,MI
# Geocoder failed.
# 370
# Compiling address
# 370 KING RD. WEST OF WESTFIELD,TRENTON,MI
# Geocoder failed.
# 371
# Compiling address
# 371 BYHALIA,MS
# Geocoder failed.
# 372
# Compiling address
# 372 BYHALIA,MS
# Geocoder failed.
# 373
# Compiling address
# 373 ST PETERSBURG,FL
# Geocoder failed.
# 374
# Compiling address
# 374 ST PETERSBURG,FL
# Geocoder failed.
# 375
# Compiling address
# 375 CHANNELVIEW,TX
# Geocoder failed.
# 376
# Compiling address
# 376 CHANNELVIEW,TX
# Geocoder failed.
# 377
# Compiling address
# 377 BRIDGEWATER,MA
# Geocoder failed.
# 378
# Compiling address
# 378 BRIDGEWATER,MA
# Geocoder failed.
# 379
# Compiling address
# 379 CLEVELAND,OH
# Geocoder failed.
# 380
# Compiling address
# 380 CLEVELAND,OH
# Geocoder failed.
# 381
# Latitude already there.
# 382
# Latitude already there.
# 383
# Compiling address
# 383 PORTSMOUTH,VA
# Geocoder failed.
# 384
# Compiling address
# 384 PORTSMOUTH,VA
# Geocoder failed.
# 385
# Compiling address
# 385 ORLANDO,FL
# Geocoder failed.
# 386
# Compiling address
# 386 ORLANDO,FL
# Geocoder failed.
# 387
# Compiling address
# 387 OPELOUSAS,LA
# Geocoder failed.
# 388
# Compiling address
# 388 OPELOUSAS,LA
# Geocoder failed.
# 389
# Compiling address
# 389 NEWBURG,MD
# Geocoder failed.
# 390
# Compiling address
# 390 NEWBURG,MD
# Geocoder failed.
# 391
# Compiling address
# 391 PEYTON,CO
# Geocoder failed.
# 392
# Compiling address
# 392 PEYTON,CO
# Geocoder failed.
# 393
# Compiling address
# 393 3890 CAMP RD.,MANISTEE,MI
# Geocoder failed.
# 394
# Compiling address
# 394 3890 CAMP RD.,MANISTEE,MI
# Geocoder failed.
# 395
# Compiling address
# 395 CUBA,MO
# Geocoder failed.
# 396
# Compiling address
# 396 CUBA,MO
# Geocoder failed.
# 397
# Compiling address
# 397 WEST MONTE,IL
# Geocoder failed.
# 398
# Compiling address
# 398 WEST MONTE,IL
# Geocoder failed.
# 399
# Compiling address
# 399 SEABECK,WA
# Geocoder failed.
# 400
# Compiling address
# 400 SEABECK,WA
# Geocoder failed.
# 401
# Compiling address
# 401 ROOSEVELT,UT
# Geocoder failed.
# 402
# Compiling address
# 402 ROOSEVELT,UT
# Geocoder failed.
# 403
# Compiling address
# 403 WEST LAKE,LA
# Geocoder failed.
# 404
# Compiling address
# 404 WEST LAKE,LA
# Geocoder failed.
# 405
# Compiling address
# 405 MERIDEN,CT
# Geocoder failed.
# 406
# Compiling address
# 406 MERIDEN,CT
# Geocoder failed.
# 407
# Compiling address
# 407 SALINAS,PR
# Geocoder failed.
# 408
# Compiling address
# 408 SALINAS,PR
# Geocoder failed.
# 409
# Compiling address
# 409 7001 SEAVIEW AVE NW,SEATTLE,WA
# Geocoder failed.
# 410
# Compiling address
# 410 7001 SEAVIEW AVE NW,SEATTLE,WA
# Geocoder failed.
# 411
# Compiling address
# 411 CHARLOTTE,NC
# Geocoder failed.
# 412
# Compiling address
# 412 CHARLOTTE,NC
# Geocoder failed.
# 413
# Compiling address
# 413 4127 HWY 361,INGLESIDE,TX
# Geocoder failed.
# 414
# Compiling address
# 414 4127 HWY 361,INGLESIDE,TX
# Geocoder failed.
# 415
# Compiling address
# 415 DETROIT,MI
# Geocoder failed.
# 416
# Compiling address
# 416 DETROIT,MI
# Geocoder failed.
# 417
# Compiling address
# 417 CAPE CHARLES,VA
# Geocoder failed.
# 418
# Compiling address
# 418 CAPE CHARLES,VA
# Geocoder failed.
# 419
# Compiling address
# 419 MIDDLETOWN,CA
# Geocoder failed.
# 420
# Compiling address
# 420 MIDDLETOWN,CA
# Geocoder failed.
# 421
# Compiling address
# 421 DALTON,GA
# Geocoder failed.
# 422
# Compiling address
# 422 DALTON,GA
# Geocoder failed.
# 423
# Compiling address
# 423 NEWTON,MA
# Geocoder failed.
# 424
# Compiling address
# 424 NEWTON,MA
# Geocoder failed.
# 425
# Compiling address
# 425 ORANGE,CA
# Geocoder failed.
# 426
# Compiling address
# 426 ORANGE,CA
# Geocoder failed.
# 427
# Compiling address
# 427 READING,CT
# Geocoder failed.
# 428
# Compiling address
# 428 READING,CT
# Geocoder failed.
# 429
# Compiling address
# 429 SAN DIEGO,CA
# Geocoder failed.
# 430
# Compiling address
# 430 SAN DIEGO,CA
# Geocoder failed.
# 431
# Compiling address
# 431 SAN DIEGO,CA
# Geocoder failed.
# 432
# Compiling address
# 432 SAN DIEGO,CA
# Geocoder failed.
# 433
# Compiling address
# 433 BURBANK,CA
# Geocoder failed.
# 434
# Compiling address
# 434 BURBANK,CA
# Geocoder failed.
# 435
# Compiling address
# 435 PASADENA,TX
# Geocoder failed.
# 436
# Compiling address
# 436 PASADENA,TX
# Geocoder failed.
# 437
# Compiling address
# 437 HACKBERRY,LA
# Geocoder failed.
# 438
# Compiling address
# 438 HACKBERRY,LA
# Geocoder failed.
# 439
# Compiling address
# 439 WILLIAMS,AZ
# Geocoder failed.
# 440
# Compiling address
# 440 WILLIAMS,AZ
# Geocoder failed.
# 441
# Compiling address
# 441 RICHMOND,VA
# Geocoder failed.
# 442
# Compiling address
# 442 RICHMOND,VA
# Geocoder failed.
# 443
# Compiling address
# 443 NEW ORLEANS,LA
# Geocoder failed.
# 444
# Compiling address
# 444 NEW ORLEANS,LA
# Geocoder failed.
# 445
# Compiling address
# 445 JACKSONVILLE,AR
# Geocoder failed.
# 446
# Compiling address
# 446 JACKSONVILLE,AR
# Geocoder failed.
# 447
# Compiling address
# 447 PALMETTO,FL
# Geocoder failed.
# 448
# Compiling address
# 448 PALMETTO,FL
# Geocoder failed.
# 449
# Compiling address
# 449 LAPORTE,TX
# Geocoder failed.
# 450
# Compiling address
# 450 LAPORTE,TX
# Geocoder failed.
# 451
# Compiling address
# 451 QUINCY,CO
# Geocoder failed.
# 452
# Compiling address
# 452 QUINCY,CO
# Geocoder failed.
# 453
# Compiling address
# 453 ZANESVILLE,OH
# Geocoder failed.
# 454
# Compiling address
# 454 ZANESVILLE,OH
# Geocoder failed.
# 455
# Compiling address
# 455 NEWPORT,OR
# Geocoder failed.
# 456
# Compiling address
# 456 NEWPORT,OR
# Geocoder failed.
# 457
# Compiling address
# 457 SANTA BARBARA,CA
# Geocoder failed.
# 458
# Compiling address
# 458 SANTA BARBARA,CA
# Geocoder failed.
# 459
# Latitude already there.
# 460
# Latitude already there.
# 461
# Compiling address
# 461 SCHUYLKILL-HAVEN,PA
# Geocoder failed.
# 462
# Compiling address
# 462 SCHUYLKILL-HAVEN,PA
# Geocoder failed.
# 463
# Compiling address
# 463 24242 HWY 1,LEEVILLE,LA
# Geocoder failed.
# 464
# Compiling address
# 464 24242 HWY 1,LEEVILLE,LA
# Geocoder failed.
# 465
# Latitude already there.
# 466
# Latitude already there.
# 467
# Compiling address
# 467 PORTLAND,OR
# Geocoder failed.
# 468
# Compiling address
# 468 PORTLAND,OR
# Geocoder failed.
# 469
# Compiling address
# 469 AGUA DILLA,PR
# Geocoder failed.
# 470
# Compiling address
# 470 AGUA DILLA,PR
# Geocoder failed.
# 471
# Compiling address
# 471 WILLIAMSTOWN,KY
# Geocoder failed.
# 472
# Compiling address
# 472 WILLIAMSTOWN,KY
# Geocoder failed.
# 473
# Latitude already there.
# 474
# Latitude already there.
# 475
# Latitude already there.
# 476
# Latitude already there.
# 477
# Compiling address
# 477 HOONAH,AK
# Geocoder failed.
# 478
# Compiling address
# 478 HOONAH,AK
# Geocoder failed.
# 479
# Compiling address
# 479 JUNEAU,AK
# Geocoder failed.
# 480
# Compiling address
# 480 JUNEAU,AK
# Geocoder failed.
# 481
# Compiling address
# 481 JUNEAU,AK
# Geocoder failed.
# 482
# Compiling address
# 482 JUNEAU,AK
# Geocoder failed.
# 483
# Compiling address
# 483 HOLLYWOOD,FL
# Geocoder failed.
# 484
# Compiling address
# 484 HOLLYWOOD,FL
# Geocoder failed.
# 485
# Latitude already there.
# 486
# Latitude already there.
# 487
# Compiling address
# 487 PROCTOR,WV
# Geocoder failed.
# 488
# Compiling address
# 488 PROCTOR,WV
# Geocoder failed.
# 489
# Compiling address
# 489 PROCTOR,WV
# Geocoder failed.
# 490
# Compiling address
# 490 PROCTOR,WV
# Geocoder failed.
# 491
# Compiling address
# 491 STATE ROUTE 2,PROCTOR,WV
# Geocoder failed.
# 492
# Compiling address
# 492 STATE ROUTE 2,PROCTOR,WV
# Geocoder failed.
# 493
# Compiling address
# 493 COLUMBUS,OH
# Geocoder failed.
# 494
# Compiling address
# 494 COLUMBUS,OH
# Geocoder failed.
# 495
# Compiling address
# 495 RUTLAND,VT
# Geocoder failed.
# 496
# Compiling address
# 496 RUTLAND,VT
# Geocoder failed.
# 497
# Compiling address
# 497 ORANGE,NJ
# Geocoder failed.
# 498
# Compiling address
# 498 ORANGE,NJ
# Geocoder failed.
# 499
# Compiling address
# 499 CHICAGO,IL
# Geocoder failed.
# 500
# Compiling address
# 500 CHICAGO,IL
# Geocoder failed.
# 501
# Compiling address
# 501 EUREKA,CA
# Geocoder failed.
# 502
# Compiling address
# 502 EUREKA,CA
# Geocoder failed.
# 503
# Compiling address
# 503 MANHATTAN,NY
# Geocoder failed.
# 504
# Compiling address
# 504 MANHATTAN,NY
# Geocoder failed.
# 505
# Latitude already there.
# 506
# Latitude already there.
# 507
# Compiling address
# 507 HOPEWELL,VA
# Geocoder failed.
# 508
# Compiling address
# 508 HOPEWELL,VA
# Geocoder failed.
# 509
# Compiling address
# 509 HOLLYWOOD,FL
# Geocoder failed.
# 510
# Compiling address
# 510 HOLLYWOOD,FL
# Geocoder failed.
# 511
# Compiling address
# 511 OREGON,OH
# Geocoder failed.
# 512
# Compiling address
# 512 OREGON,OH
# Geocoder failed.
# 513
# Compiling address
# 513 SAN PEDRO,CA
# Geocoder failed.
# 514
# Compiling address
# 514 SAN PEDRO,CA
# Geocoder failed.
# 515
# Compiling address
# 515 UPPER COURT ST,BINGHAMPTON,NY
# Geocoder failed.
# 516
# Compiling address
# 516 UPPER COURT ST,BINGHAMPTON,NY
# Geocoder failed.
# 517
# Compiling address
# 517 US HIGHWAY 431 & HAPPY HILL RD,BOAZ,AL
# Geocoder failed.
# 518
# Compiling address
# 518 US HIGHWAY 431 & HAPPY HILL RD,BOAZ,AL
# Geocoder failed.
# 519
# Latitude already there.
# 520
# Latitude already there.
# 521
# Compiling address
# 521 8305 OTTO RD.,CHEYENNE,WY
# Geocoder failed.
# 522
# Compiling address
# 522 8305 OTTO RD.,CHEYENNE,WY
# Geocoder failed.
# 523
# Compiling address
# 523 UNDERNEATH BEACH LANE BRIDGE,WESTHAMPTON BEACH,NY
# Geocoder failed.
# 524
# Compiling address
# 524 UNDERNEATH BEACH LANE BRIDGE,WESTHAMPTON BEACH,NY
# Geocoder failed.
# 525
# Compiling address
# 525 HOUSTON,TX
# Geocoder failed.
# 526
# Compiling address
# 526 HOUSTON,TX
# Geocoder failed.
# 527
# Compiling address
# 527 PORTSMOUTH,VA
# Geocoder failed.
# 528
# Compiling address
# 528 PORTSMOUTH,VA
# Geocoder failed.
# 529
# Compiling address
# 529 QUITMAN,GA
# Geocoder failed.
# 530
# Compiling address
# 530 QUITMAN,GA
# Geocoder failed.
# 531
# Compiling address
# 531 SOUTH BEND,IN
# Geocoder failed.
# 532
# Compiling address
# 532 SOUTH BEND,IN
# Geocoder failed.
# 533
# Compiling address
# 533 PORT CANAVERAL,FL
# Geocoder failed.
# 534
# Compiling address
# 534 PORT CANAVERAL,FL
# Geocoder failed.
# 535
# Compiling address
# 535 LOUISVILLE,KY
# Geocoder failed.
# 536
# Compiling address
# 536 LOUISVILLE,KY
# Geocoder failed.
# 537
# Compiling address
# 537 MIAMI BEACH,FL
# Geocoder failed.
# 538
# Compiling address
# 538 MIAMI BEACH,FL
# Geocoder failed.
# 539
# Compiling address
# 539 MONTE VISTA,CO
# Geocoder failed.
# 540
# Compiling address
# 540 MONTE VISTA,CO
# Geocoder failed.
# 541
# Compiling address
# 541 MONTAUK,NY
# Geocoder failed.
# 542
# Compiling address
# 542 MONTAUK,NY
# Geocoder failed.
# 543
# Compiling address
# 543 HOLBROOK,NY
# Geocoder failed.
# 544
# Compiling address
# 544 HOLBROOK,NY
# Geocoder failed.
# 545
# Compiling address
# 545 BAYONNE,NJ
# Geocoder failed.
# 546
# Compiling address
# 546 BAYONNE,NJ
# Geocoder failed.
# 547
# Compiling address
# 547 ORMOND BEACH,FL
# Geocoder failed.
# 548
# Compiling address
# 548 ORMOND BEACH,FL
# Geocoder failed.
# 549
# Latitude already there.
# 550
# Latitude already there.
# 551
# Latitude already there.
# 552
# Latitude already there.
# 553
# Compiling address
# 553 FRANKFORT,KY
# Geocoder failed.
# 554
# Compiling address
# 554 FRANKFORT,KY
# Geocoder failed.
# 555
# Latitude already there.
# 556
# Latitude already there.
# 557
# Compiling address
# 557 RIVERSIDE,CA
# Geocoder failed.
# 558
# Compiling address
# 558 RIVERSIDE,CA
# Geocoder failed.
# 559
# Compiling address
# 559 HILLSBOROUGH,NC
# Geocoder failed.
# 560
# Compiling address
# 560 HILLSBOROUGH,NC
# Geocoder failed.
# 561
# Compiling address
# 561 MOLINE,IL
# Geocoder failed.
# 562
# Compiling address
# 562 MOLINE,IL
# Geocoder failed.
# 563
# Compiling address
# 563 101 MCKENZIE RD.,BONAIRE,GA
# Geocoder failed.
# 564
# Compiling address
# 564 101 MCKENZIE RD.,BONAIRE,GA
# Geocoder failed.
# 565
# Latitude already there.
# 566
# Latitude already there.
# 567
# Compiling address
# 567 AUSTELL,GA
# Geocoder failed.
# 568
# Compiling address
# 568 AUSTELL,GA
# Geocoder failed.
# 569
# Compiling address
# 569 PELL CITY,AL
# Geocoder failed.
# 570
# Compiling address
# 570 PELL CITY,AL
# Geocoder failed.
# 571
# Compiling address
# 571 ST. ROSE,LA
# Geocoder failed.
# 572
# Compiling address
# 572 ST. ROSE,LA
# Geocoder failed.
# 573
# Compiling address
# 573 END OF LADUE ROAD OFF OF BROWN MOUNTAIN RD.,IRON MOUNTAIN LAKE,MO
# Geocoder failed.
# 574
# Compiling address
# 574 END OF LADUE ROAD OFF OF BROWN MOUNTAIN RD.,IRON MOUNTAIN LAKE,MO
# Geocoder failed.
# 575
# Compiling address
# 575 SALT LAKE CITY,UT
# Geocoder failed.
# 576
# Compiling address
# 576 SALT LAKE CITY,UT
# Geocoder failed.
# 577
# Compiling address
# 577 GRANDVIEW,WA
# Geocoder failed.
# 578
# Compiling address
# 578 GRANDVIEW,WA
# Geocoder failed.
# 579
# Latitude already there.
# 580
# Latitude already there.
# 581
# Compiling address
# 581 WAIMEA,HI
# Geocoder failed.
# 582
# Compiling address
# 582 WAIMEA,HI
# Geocoder failed.
# 583
# Compiling address
# 583 BELLINGHAM,WA
# Geocoder failed.
# 584
# Compiling address
# 584 BELLINGHAM,WA
# Geocoder failed.
# 585
# Compiling address
# 585 2204 MERRICK RD.,MERRICK,NY
# Geocoder failed.
# 586
# Compiling address
# 586 2204 MERRICK RD.,MERRICK,NY
# Geocoder failed.
# 587
# Compiling address
# 587 POCATELLO,ID
# Geocoder failed.
# 588
# Compiling address
# 588 POCATELLO,ID
# Geocoder failed.
# 589
# Compiling address
# 589 MEMPHIS,TN
# Geocoder failed.
# 590
# Compiling address
# 590 MEMPHIS,TN
# Geocoder failed.
# 591
# Compiling address
# 591 BELLEVILLE,NJ
# Geocoder failed.
# 592
# Compiling address
# 592 BELLEVILLE,NJ
# Geocoder failed.
# 593
# Compiling address
# 593 HACKBERRY,LA
# Geocoder failed.
# 594
# Compiling address
# 594 HACKBERRY,LA
# Geocoder failed.
# 595
# Compiling address
# 595 GRAND AVE GRADE CROSSING,SANTA ANA,CA
# Geocoder failed.
# 596
# Compiling address
# 596 GRAND AVE GRADE CROSSING,SANTA ANA,CA
# Geocoder failed.
# 597
# Compiling address
# 597 CRANSTON,RI
# Geocoder failed.
# 598
# Compiling address
# 598 CRANSTON,RI
# Geocoder failed.
# 599
# Compiling address
# 599 3 MI WEST ON U.S. HWY 60,PAMPA,TX
# Geocoder failed.
# 600
# Compiling address
# 600 3 MI WEST ON U.S. HWY 60,PAMPA,TX
# Geocoder failed.
# 601
# Compiling address
# 601 VIRGINIA BEACH,VA
# Geocoder failed.
# 602
# Compiling address
# 602 VIRGINIA BEACH,VA
# Geocoder failed.
# 603
# Compiling address
# 603 WILLIS,TX
# Geocoder failed.
# 604
# Compiling address
# 604 WILLIS,TX
# Geocoder failed.
# 605
# Compiling address
# 605 INTERSECTION OF COLLEGE AVE AND WARE ST,ATHENS,GA
# Geocoder failed.
# 606
# Compiling address
# 606 INTERSECTION OF COLLEGE AVE AND WARE ST,ATHENS,GA
# Geocoder failed.
# 607
# Latitude already there.
# 608
# Latitude already there.
# 609
# Compiling address
# 609 NORTH FORT MEYERS,FL
# Geocoder failed.
# 610
# Compiling address
# 610 NORTH FORT MEYERS,FL
# Geocoder failed.
# 611
# Compiling address
# 611 102 AUBURN WAY NORTH,AUBURN,WA
# Geocoder failed.
# 612
# Compiling address
# 612 102 AUBURN WAY NORTH,AUBURN,WA
# Geocoder failed.
# 613
# Compiling address
# 613 TAMPA,FL
# Geocoder failed.
# 614
# Compiling address
# 614 TAMPA,FL
# Geocoder failed.
# 615
# Latitude already there.
# 616
# Latitude already there.
# 617
# Latitude already there.
# 618
# Latitude already there.
# 619
# Compiling address
# 619 BYHALIA,MS
# Geocoder failed.
# 620
# Compiling address
# 620 BYHALIA,MS
# Geocoder failed.
# 621
# Compiling address
# 621 SUWANEE,GA
# Geocoder failed.
# 622
# Compiling address
# 622 SUWANEE,GA
# Geocoder failed.
# 623
# Compiling address
# 623 NEW PLYMOUTH,OH
# Geocoder failed.
# 624
# Compiling address
# 624 NEW PLYMOUTH,OH
# Geocoder failed.
# 625
# Compiling address
# 625 NORTH FORT MEYERS,FL
# Geocoder failed.
# 626
# Compiling address
# 626 NORTH FORT MEYERS,FL
# Geocoder failed.
# 627
# Compiling address
# 627 PORTLAND,OR
# Geocoder failed.
# 628
# Compiling address
# 628 PORTLAND,OR
# Geocoder failed.
# 629
# Compiling address
# 629 WILMINGTON,DE
# Geocoder failed.
# 630
# Compiling address
# 630 WILMINGTON,DE
# Geocoder failed.
# 631
# Compiling address
# 631 AMELIA,LA
# Geocoder failed.
# 632
# Compiling address
# 632 AMELIA,LA
# Geocoder failed.
# 633
# Compiling address
# 633 PENSACOLA,FL
# Geocoder failed.
# 634
# Compiling address
# 634 PENSACOLA,FL
# Geocoder failed.
# 635
# Compiling address
# 635 MIAMI,FL
# Geocoder failed.
# 636
# Compiling address
# 636 MIAMI,FL
# Geocoder failed.
# 637
# Compiling address
# 637 MIAMI,FL
# Geocoder failed.
# 638
# Compiling address
# 638 MIAMI,FL
# Geocoder failed.
# 639
# Compiling address
# 639 NORTH LITTLE ROCK,AR
# Geocoder failed.
# 640
# Compiling address
# 640 NORTH LITTLE ROCK,AR
# Geocoder failed.
# 641
# Latitude already there.
# 642
# Latitude already there.
# 643
# Compiling address
# 643 OKLAHOMA CITY,OK
# Geocoder failed.
# 644
# Compiling address
# 644 OKLAHOMA CITY,OK
# Geocoder failed.
# 645
# Compiling address
# 645 PAWHUSKA,OK
# Geocoder failed.
# 646
# Compiling address
# 646 PAWHUSKA,OK
# Geocoder failed.
# 647
# Compiling address
# 647 GRAND MARAIS,MI
# Geocoder failed.
# 648
# Compiling address
# 648 GRAND MARAIS,MI
# Geocoder failed.
# 649
# Compiling address
# 649 PRINCETON,IN
# Geocoder failed.
# 650
# Compiling address
# 650 PRINCETON,IN
# Geocoder failed.
# 651
# Compiling address
# 651 HERNANDO BEACH,FL
# Geocoder failed.
# 652
# Compiling address
# 652 HERNANDO BEACH,FL
# Geocoder failed.
# 653
# Compiling address
# 653 HALF MOON BAY,CA
# Geocoder failed.
# 654
# Compiling address
# 654 HALF MOON BAY,CA
# Geocoder failed.
# 655
# Compiling address
# 655 TUCSON,AZ
# Geocoder failed.
# 656
# Compiling address
# 656 TUCSON,AZ
# Geocoder failed.
# 657
# Compiling address
# 657 HOUMA,LA
# Geocoder failed.
# 658
# Compiling address
# 658 HOUMA,LA
# Geocoder failed.
# 659
# Compiling address
# 659 128 BAILEY FARM RD.,ORANGE,NY
# Geocoder failed.
# 660
# Compiling address
# 660 128 BAILEY FARM RD.,ORANGE,NY
# Geocoder failed.
# 661
# Compiling address
# 661 TULSA,OK
# Geocoder failed.
# 662
# Compiling address
# 662 TULSA,OK
# Geocoder failed.
# 663
# Compiling address
# 663 PARKERSBURG,WV
# Geocoder failed.
# 664
# Compiling address
# 664 PARKERSBURG,WV
# Geocoder failed.
# 665
# Compiling address
# 665 CORPUS CHRISTI,TX
# Geocoder failed.
# 666
# Compiling address
# 666 CORPUS CHRISTI,TX
# Geocoder failed.
# 667
# Latitude already there.
# 668
# Latitude already there.
# 669
# Compiling address
# 669 EDGEWOOD,WA
# Geocoder failed.
# 670
# Compiling address
# 670 EDGEWOOD,WA
# Geocoder failed.
# 671
# Compiling address
# 671 BUCKLEY,WA
# Geocoder failed.
# 672
# Compiling address
# 672 BUCKLEY,WA
# Geocoder failed.
# 673
# Compiling address
# 673 PELL CITY,AL
# Geocoder failed.
# 674
# Compiling address
# 674 PELL CITY,AL
# Geocoder failed.
# 675
# Compiling address
# 675 SPARTANBURG,SC
# Geocoder failed.
# 676
# Compiling address
# 676 SPARTANBURG,SC
# Geocoder failed.
# 677
# Compiling address
# 677 NEAR UTICA AVENUE STATION,BROOKLYN,NY
# Geocoder failed.
# 678
# Compiling address
# 678 NEAR UTICA AVENUE STATION,BROOKLYN,NY
# Geocoder failed.
# 679
# Compiling address
# 679 WEST LIBERTY,KY
# Geocoder failed.
# 680
# Compiling address
# 680 WEST LIBERTY,KY
# Geocoder failed.
# 681
# Compiling address
# 681 MOBILE,AL
# Geocoder failed.
# 682
# Compiling address
# 682 MOBILE,AL
# Geocoder failed.
# 683
# Compiling address
# 683 PELHAM,AL
# Geocoder failed.
# 684
# Compiling address
# 684 PELHAM,AL
# Geocoder failed.
# 685
# Compiling address
# 685 CORPUS CHRISTI,TX
# Geocoder failed.
# 686
# Compiling address
# 686 CORPUS CHRISTI,TX
# Geocoder failed.
# 687
# Compiling address
# 687 KOKOMO,IN
# Geocoder failed.
# 688
# Compiling address
# 688 KOKOMO,IN
# Geocoder failed.
# 689
# Compiling address
# 689 ATLANTA,GA
# Geocoder failed.
# 690
# Compiling address
# 690 ATLANTA,GA
# Geocoder failed.
# 691
# Compiling address
# 691 FORT WORTH,TX
# Geocoder failed.
# 692
# Compiling address
# 692 FORT WORTH,TX
# Geocoder failed.
# 693
# Compiling address
# 693 SEATTLE,WA
# Geocoder failed.
# 694
# Compiling address
# 694 SEATTLE,WA
# Geocoder failed.
# 695
# Compiling address
# 695 CONWAY,AR
# Geocoder failed.
# 696
# Compiling address
# 696 CONWAY,AR
# Geocoder failed.
# 697
# Compiling address
# 697 COINJOCK,NC
# Geocoder failed.
# 698
# Compiling address
# 698 COINJOCK,NC
# Geocoder failed.
# 699
# Compiling address
# 699 WESTERLY,RI
# Geocoder failed.
# 700
# Compiling address
# 700 WESTERLY,RI
# Geocoder failed.
# 701
# Compiling address
# 701 LEXINGTON,NE
# Geocoder failed.
# 702
# Compiling address
# 702 LEXINGTON,NE
# Geocoder failed.
# 703
# Compiling address
# 703 WELLS,NV
# Geocoder failed.
# 704
# Compiling address
# 704 WELLS,NV
# Geocoder failed.
# 705
# Compiling address
# 705 DAYTON,WA
# Geocoder failed.
# 706
# Compiling address
# 706 DAYTON,WA
# Geocoder failed.
# 707
# Compiling address
# 707 JACKSONVILLE,FL
# Geocoder failed.
# 708
# Compiling address
# 708 JACKSONVILLE,FL
# Geocoder failed.
# 709
# Latitude already there.
# 710
# Latitude already there.
# 711
# Compiling address
# 711 1957 TYSON CHAPEL CHURCH RD.,FARMVILLE,NC
# Geocoder failed.
# 712
# Compiling address
# 712 1957 TYSON CHAPEL CHURCH RD.,FARMVILLE,NC
# Geocoder failed.
# 713
# Compiling address
# 713 GREEN CANYON AREA COUNTY,LA
# Geocoder failed.
# 714
# Compiling address
# 714 GREEN CANYON AREA COUNTY,LA
# Geocoder failed.
# 715
# Compiling address
# 715 PEOTONE,IL
# Geocoder failed.
# 716
# Compiling address
# 716 PEOTONE,IL
# Geocoder failed.
# 717
# Compiling address
# 717 LITTLE ROCK,AR
# Geocoder failed.
# 718
# Compiling address
# 718 LITTLE ROCK,AR
# Geocoder failed.
# 719
# Compiling address
# 719 LEEVILLE,LA
# Geocoder failed.
# 720
# Compiling address
# 720 LEEVILLE,LA
# Geocoder failed.
# 721
# Compiling address
# 721 KALAMA,WA
# Geocoder failed.
# 722
# Compiling address
# 722 KALAMA,WA
# Geocoder failed.
# 723
# Compiling address
# 723 JACKSON,MI
# Geocoder failed.
# 724
# Compiling address
# 724 JACKSON,MI
# Geocoder failed.
# 725
# Compiling address
# 725 1145 HARBOR WAY SOUTH,RICHMOND,CA
# Geocoder failed.
# 726
# Compiling address
# 726 1145 HARBOR WAY SOUTH,RICHMOND,CA
# Geocoder failed.
# 727
# Compiling address
# 727 HARBOR CITY,CA
# Geocoder failed.
# 728
# Compiling address
# 728 HARBOR CITY,CA
# Geocoder failed.
# 729
# Compiling address
# 729 HILLSBORO,OR
# Geocoder failed.
# 730
# Compiling address
# 730 HILLSBORO,OR
# Geocoder failed.
# 731
# Compiling address
# 731 39018 HIGHWAY 3089,DONALDSONVILLE,LA
# Geocoder failed.
# 732
# Compiling address
# 732 39018 HIGHWAY 3089,DONALDSONVILLE,LA
# Geocoder failed.
# 733
# Compiling address
# 733 LIHUE,HI
# Geocoder failed.
# 734
# Compiling address
# 734 LIHUE,HI
# Geocoder failed.
# 735
# Compiling address
# 735 UNKNOWN SHEEN - CREEK - MAIN STREET AND BOONSLICK RD. - NEAR FRONTIER PARK,ST. CHARLES,MO
# Geocoder failed.
# 736
# Compiling address
# 736 UNKNOWN SHEEN - CREEK - MAIN STREET AND BOONSLICK RD. - NEAR FRONTIER PARK,ST. CHARLES,MO
# Geocoder failed.
# 737
# Compiling address
# 737 CROWLEY,TX
# Geocoder failed.
# 738
# Compiling address
# 738 CROWLEY,TX
# Geocoder failed.
# 739
# Compiling address
# 739 INDEPENDENCE,MO
# Geocoder failed.
# 740
# Compiling address
# 740 INDEPENDENCE,MO
# Geocoder failed.
# 741
# Compiling address
# 741 ENID,OK
# Geocoder failed.
# 742
# Compiling address
# 742 ENID,OK
# Geocoder failed.
# 743
# Compiling address
# 743 16330 LOWER HARBOR RD.,BROOKINGS,OR
# Geocoder failed.
# 744
# Compiling address
# 744 16330 LOWER HARBOR RD.,BROOKINGS,OR
# Geocoder failed.
# 745
# Compiling address
# 745 WEAVER,IA
# Geocoder failed.
# 746
# Compiling address
# 746 WEAVER,IA
# Geocoder failed.
# 747
# Compiling address
# 747 WAUWATOSA,WI
# Geocoder failed.
# 748
# Compiling address
# 748 WAUWATOSA,WI
# Geocoder failed.
# 749
# Compiling address
# 749 PITI,GU
# Geocoder failed.
# 750
# Compiling address
# 750 PITI,GU
# Geocoder failed.
# 751
# Compiling address
# 751 GREENWOOD,WI
# Geocoder failed.
# 752
# Compiling address
# 752 GREENWOOD,WI
# Geocoder failed.
# 753
# Compiling address
# 753 CONCORIA,MO
# Geocoder failed.
# 754
# Compiling address
# 754 CONCORIA,MO
# Geocoder failed.
# 755
# Compiling address
# 755 ROOSEVELT,CA
# Geocoder failed.
# 756
# Compiling address
# 756 ROOSEVELT,CA
# Geocoder failed.
# 757
# Compiling address
# 757 FRESNO,CA
# Geocoder failed.
# 758
# Compiling address
# 758 FRESNO,CA
# Geocoder failed.
# 759
# Compiling address
# 759 MILWAUKIE,OR
# Geocoder failed.
# 760
# Compiling address
# 760 MILWAUKIE,OR
# Geocoder failed.
# 761
# Compiling address
# 761 PASADENA,TX
# Geocoder failed.
# 762
# Compiling address
# 762 PASADENA,TX
# Geocoder failed.
# 763
# Compiling address
# 763 FREEPORT,TX
# Geocoder failed.
# 764
# Compiling address
# 764 FREEPORT,TX
# Geocoder failed.
# 765
# Compiling address
# 765 WHITE PINE,TN
# Geocoder failed.
# 766
# Compiling address
# 766 WHITE PINE,TN
# Geocoder failed.
# 767
# Compiling address
# 767 POINT COMFORT,TX
# Geocoder failed.
# 768
# Compiling address
# 768 POINT COMFORT,TX
# Geocoder failed.
# 769
# Compiling address
# 769 HOUSTON,TX
# Geocoder failed.
# 770
# Compiling address
# 770 HOUSTON,TX
# Geocoder failed.
# 771
# Compiling address
# 771 FORT MEYERS BEACH,FL
# Geocoder failed.
# 772
# Compiling address
# 772 FORT MEYERS BEACH,FL
# Geocoder failed.
# 773
# Compiling address
# 773 47201 COUNTY ROAD 273,CONESVILLE,OH
# Geocoder failed.
# 774
# Compiling address
# 774 47201 COUNTY ROAD 273,CONESVILLE,OH
# Geocoder failed.
# 775
# Compiling address
# 775 1/2 MILE S FROM HIGHWAY 140,GUSTINE,CA
# Geocoder failed.
# 776
# Compiling address
# 776 1/2 MILE S FROM HIGHWAY 140,GUSTINE,CA
# Geocoder failed.
# 777
# Compiling address
# 777 ASHEVILLE,NC
# Geocoder failed.
# 778
# Compiling address
# 778 ASHEVILLE,NC
# Geocoder failed.
# 779
# Compiling address
# 779 BURLINGTON,NC
# Geocoder failed.
# 780
# Compiling address
# 780 BURLINGTON,NC
# Geocoder failed.
# 781
# Compiling address
# 781 FEURA BUSH,NY
# Geocoder failed.
# 782
# Compiling address
# 782 FEURA BUSH,NY
# Geocoder failed.
# 783
# Compiling address
# 783 SOLSBERRY,IN
# Geocoder failed.
# 784
# Compiling address
# 784 SOLSBERRY,IN
# Geocoder failed.
# 785
# Compiling address
# 785 SWEETSPRINGS,MO
# Geocoder failed.
# 786
# Compiling address
# 786 SWEETSPRINGS,MO
# Geocoder failed.
# 787
# Compiling address
# 787 SAN JUAN,PR
# Geocoder failed.
# 788
# Compiling address
# 788 SAN JUAN,PR
# Geocoder failed.
# 789
# Latitude already there.
# 790
# Latitude already there.
# 791
# Compiling address
# 791 GILCREST,CO
# Geocoder failed.
# 792
# Compiling address
# 792 GILCREST,CO
# Geocoder failed.
# 793
# Compiling address
# 793 SELLERSVILLE,PA
# Geocoder failed.
# 794
# Compiling address
# 794 SELLERSVILLE,PA
# Geocoder failed.
# 795
# Compiling address
# 795 ELGIN,IL
# Geocoder failed.
# 796
# Compiling address
# 796 ELGIN,IL
# Geocoder failed.
# 797
# Compiling address
# 797 SAN DIEGO,CA
# Geocoder failed.
# 798
# Compiling address
# 798 SAN DIEGO,CA
# Geocoder failed.
# 799
# Latitude already there.
# 800
# Latitude already there.
# 801
# Compiling address
# 801 SAN JUAN,PR
# Geocoder failed.
# 802
# Compiling address
# 802 SAN JUAN,PR
# Geocoder failed.
# 803
# Compiling address
# 803 ON HWY 243,RUSSELLVILLE,AL
# Geocoder failed.
# 804
# Compiling address
# 804 ON HWY 243,RUSSELLVILLE,AL
# Geocoder failed.
# 805
# Latitude already there.
# 806
# Latitude already there.
# 807
# Compiling address
# 807 BAYONNE,NJ
# Geocoder failed.
# 808
# Compiling address
# 808 BAYONNE,NJ
# Geocoder failed.
# 809
# Compiling address
# 809 PENUELAS,PR
# Geocoder failed.
# 810
# Compiling address
# 810 PENUELAS,PR
# Geocoder failed.
# 811
# Compiling address
# 811 OXNARD,CA
# Geocoder failed.
# 812
# Compiling address
# 812 OXNARD,CA
# Geocoder failed.
# 813
# Compiling address
# 813 BAY ST. LOUIS,MS
# Geocoder failed.
# 814
# Compiling address
# 814 BAY ST. LOUIS,MS
# Geocoder failed.
# 815
# Compiling address
# 815 RICHMOND,CA
# Geocoder failed.
# 816
# Compiling address
# 816 RICHMOND,CA
# Geocoder failed.
# 817
# Compiling address
# 817 ATLANTA,GA
# Geocoder failed.
# 818
# Compiling address
# 818 ATLANTA,GA
# Geocoder failed.
# 819
# Compiling address
# 819 NEDERLAND,TX
# Geocoder failed.
# 820
# Compiling address
# 820 NEDERLAND,TX
# Geocoder failed.
# 821
# Compiling address
# 821 BELLINGHAM,WA
# Geocoder failed.
# 822
# Compiling address
# 822 BELLINGHAM,WA
# Geocoder failed.
# 823
# Compiling address
# 823 SEATTLE,WA
# Geocoder failed.
# 824
# Compiling address
# 824 SEATTLE,WA
# Geocoder failed.
# 825
# Compiling address
# 825 CHICKASAW,AL
# Geocoder failed.
# 826
# Compiling address
# 826 CHICKASAW,AL
# Geocoder failed.
# 827
# Compiling address
# 827 STATE RD 144 EAST OF MANN ROAD,MOORESVILLE,IN
# Geocoder failed.
# 828
# Compiling address
# 828 STATE RD 144 EAST OF MANN ROAD,MOORESVILLE,IN
# Geocoder failed.
# 829
# Compiling address
# 829 ACROSS THE STREET FROM THE CORNER OF 3RD STREET AND MOSS AVE.,ODESSA,TX
# Geocoder failed.
# 830
# Compiling address
# 830 ACROSS THE STREET FROM THE CORNER OF 3RD STREET AND MOSS AVE.,ODESSA,TX
# Geocoder failed.
# 831
# Latitude already there.
# 832
# Latitude already there.
# 833
# Compiling address
# 833 EDEN,NC
# Geocoder failed.
# 834
# Compiling address
# 834 EDEN,NC
# Geocoder failed.
# 835
# Compiling address
# 835 BLOOMINGTON,CA
# Geocoder failed.
# 836
# Compiling address
# 836 BLOOMINGTON,CA
# Geocoder failed.
# 837
# Compiling address
# 837 SAN DIEGO,CA
# Geocoder failed.
# 838
# Compiling address
# 838 SAN DIEGO,CA
# Geocoder failed.
# 839
# Compiling address
# 839 RURAL RETREAT,VA
# Geocoder failed.
# 840
# Compiling address
# 840 RURAL RETREAT,VA
# Geocoder failed.
# 841
# Compiling address
# 841 COSTA MESA,CA
# Geocoder failed.
# 842
# Compiling address
# 842 COSTA MESA,CA
# Geocoder failed.
# 843
# Compiling address
# 843 CORAOPOLIS,PA
# Geocoder failed.
# 844
# Compiling address
# 844 CORAOPOLIS,PA
# Geocoder failed.
# 845
# Compiling address
# 845 MILL CITY,OR
# Geocoder failed.
# 846
# Compiling address
# 846 MILL CITY,OR
# Geocoder failed.
# 847
# Latitude already there.
# 848
# Latitude already there.
# 849
# Compiling address
# 849 DUPONT,WA
# Geocoder failed.
# 850
# Compiling address
# 850 DUPONT,WA
# Geocoder failed.
# 851
# Compiling address
# 851 ARVADA,CO
# Geocoder failed.
# 852
# Compiling address
# 852 ARVADA,CO
# Geocoder failed.
# 853
# Compiling address
# 853 EFFINGHAM,IL
# Geocoder failed.
# 854
# Compiling address
# 854 EFFINGHAM,IL
# Geocoder failed.
# 855
# Compiling address
# 855 ANAHEIM,CA
# Geocoder failed.
# 856
# Compiling address
# 856 ANAHEIM,CA
# Geocoder failed.
# 857
# Compiling address
# 857 HACKBERRY,LA
# Geocoder failed.
# 858
# Compiling address
# 858 HACKBERRY,LA
# Geocoder failed.
# 859
# Compiling address
# 859 7001 SEAVIEW AVE NW,SEATTLE,WA
# Geocoder failed.
# 860
# Compiling address
# 860 7001 SEAVIEW AVE NW,SEATTLE,WA
# Geocoder failed.
# 861
# Compiling address
# 861 FT LEWIS,WA
# Geocoder failed.
# 862
# Compiling address
# 862 FT LEWIS,WA
# Geocoder failed.
# 863
# ...
# Geocoder failed.
# 1273
# Compiling address
# 1273 MIDDLETOWN,DE
# Geocoder failed.
# 1274
# Compiling address
# 1274 STATE ROUTE 42,MANSFIELD,OH
# Geocoder failed.
# 1275
# Compiling address
# 1275 PERU,IL
# Geocoder failed.
# 1276
# Compiling address
# 1276 SUMNER,WA
# Geocoder failed.
# 1277
# Latitude already there.
# 1278
# Compiling address
# 1278 NEW YORK,NY
# Geocoder failed.
# 1279
# Compiling address
# 1279 MIAMI,FL
# Geocoder failed.
# 1280
# Compiling address
# 1280 HOUSTON,TX
# Geocoder failed.
# 1281
# Compiling address
# 1281 GALVESTON,TX
# Geocoder failed.
# 1282
# Compiling address
# 1282 SEATTLE,WA
# Geocoder failed.
# 1283
# Compiling address
# 1283 SAINT AUGUSTINE,FL
# Geocoder failed.
# 1284
# Compiling address
# 1284 SAN DIEGO,CA
# Geocoder failed.
# 1285
# Compiling address
# 1285 MIDWEST,WY
# Geocoder failed.
# 1286
# Compiling address
# 1286 ALAMEDA,CA
# Geocoder failed.
# 1287
# Compiling address
# 1287 RIVIERA BEACH,FL
# Geocoder failed.
# 1288
# Compiling address
# 1288 REFUGIO,TX
# Geocoder failed.
# 1289
# Latitude already there.
# 1290
# Compiling address
# 1290 MOORESBORO,NC
# Geocoder failed.
# 1291
# Compiling address
# 1291 HARRISON TOWNSHIP,MI
# Geocoder failed.
# 1292
# Compiling address
# 1292 SIMI VALLEY,CA
# Geocoder failed.
# 1293
# Compiling address
# 1293 PORUM,OK
# Geocoder failed.
# 1294
# Compiling address
# 1294 PENSACOLA,FL
# Geocoder failed.
# 1295
# Compiling address
# 1295 WEST LAKE,LA
# Geocoder failed.
# 1296
# Compiling address
# 1296 FORT PAYNE,AL
# Geocoder failed.
# 1297
# Compiling address
# 1297  IDAHO FALLS,ID
# Geocoder failed.
# 1298
# Compiling address
# 1298 INTERSECTION OF LOWER LANDING ROAD & BLACK HORSE PIKE,GLOUCESTER TOWNSHIP,NJ
# Geocoder failed.
# 1299
# Compiling address
# 1299 WEST BOUNTIFUL,UT
# Geocoder failed.
# 1300
# Compiling address
# 1300 LOS ANGELES,CA
# Geocoder failed.
# 1301
# Latitude already there.
# 1302
# Compiling address
# 1302 18560 E STATE ROUTE 3,ALLYN,WA
# Geocoder failed.
# 1303
# Compiling address
# 1303 VERO BEACH,FL
# Geocoder failed.
# 1304
# Compiling address
# 1304 GALVESTON,TX
# Geocoder failed.
# 1305
# Compiling address
# 1305 MANHATTAN,NY
# Geocoder failed.
# 1306
# Compiling address
# 1306 PROVO,UT
# Geocoder failed.
# 1307
# Compiling address
# 1307 GALVESTON COUNTY,TX
# Geocoder failed.
# 1308
# Compiling address
# 1308 CAROLINA,PR
# Geocoder failed.
# 1309
# Compiling address
# 1309 ANACORTES,WA
# Geocoder failed.
# 1310
# Compiling address
# 1310 CATLETTSBURG,KY
# Geocoder failed.
# 1311
# Compiling address
# 1311 MARSHALL,IL
# Geocoder failed.
# 1312
# Compiling address
# 1312 DELAWARE,OH
# Geocoder failed.
# 1313
# Compiling address
# 1313 HOUSTON,TX
# Geocoder failed.
# 1314
# Compiling address
# 1314 STATESVILLE,NC
# Geocoder failed.
# 1315
# Compiling address
# 1315 CORNER OF BRIGGS ST OR BRIGGS ROAD AND LIBERTY STREET,DURHAM,NC
# Geocoder failed.
# 1316
# Compiling address
# 1316 WINTHROP,MN
# Geocoder failed.
# 1317
# Compiling address
# 1317 PENSACOLA,FL
# Geocoder failed.
# 1318
# Compiling address
# 1318 TUPELO,MS
# Geocoder failed.
# 1319
# Compiling address
# 1319 NEW ORLEANS,LA
# Geocoder failed.
# 1320
# Compiling address
# 1320 LONG BEACH,CA
# Geocoder failed.
# 1321
# Compiling address
# 1321 SYRACUSE,NY
# Geocoder failed.
# 1322
# Compiling address
# 1322 VAN BUREN,AR
# Geocoder failed.
# 1323
# Compiling address
# 1323 WEST PALM BEACH,FL
# Geocoder failed.
# 1324
# Compiling address
# 1324 605 N COUNTY HWY 393,SANTA ROSA BEACH,FL
# Geocoder failed.
# 1325
# Compiling address
# 1325 GREENSBORO,NC
# Geocoder failed.
# 1326
# Compiling address
# 1326 GREENSBORO,NC
# Geocoder failed.
# 1327
# Compiling address
# 1327 PEORIA,AZ
# Geocoder failed.
# 1328
# Compiling address
# 1328 SAN DIEGO,CA
# Geocoder failed.
# 1329
# Compiling address
# 1329 SUN VALLEY,CA
# Geocoder failed.
# 1330
# Compiling address
# 1330 ELVERSON,PA
# Geocoder failed.
# 1331
# Compiling address
# 1331 EVANS,CO
# Geocoder failed.
# 1332
# Compiling address
# 1332 HAMMOND,LA
# Geocoder failed.
# 1333
# Latitude already there.
# 1334
# Compiling address
# 1334 DRAPER,UT
# Geocoder failed.
# 1335
# Compiling address
# 1335 CHARLOTTE,NC
# Geocoder failed.
# 1336
# Latitude already there.
# 1337
# Compiling address
# 1337 ST JAMES,LA
# Geocoder failed.
# 1338
# Compiling address
# 1338 SPRINGFIELD,MO
# Geocoder failed.
# 1339
# Compiling address
# 1339 LEALMAN,FL
# Geocoder failed.
# 1340
# Compiling address
# 1340 MARTINEZ,GA
# Geocoder failed.
# 1341
# Latitude already there.
# 1342
# Compiling address
# 1342 HACKBERRY,LA
# Geocoder failed.
# 1343
# Compiling address
# 1343 CRESCENT CITY,FL
# Geocoder failed.
# 1344
# Compiling address
# 1344 HOUSTON,TX
# Geocoder failed.
# 1345
# Compiling address
# 1345 DUNCANVILLE,TX
# Geocoder failed.
# 1346
# Compiling address
# 1346 PITI,GU
# Geocoder failed.
# 1347
# Compiling address
# 1347 SOUTHERN BLVD & CRESTWOOD,WEST PALM BEACH,FL
# Geocoder failed.
# 1348
# Latitude already there.
# 1349
# Compiling address
# 1349 111 PARK PLACE DRIVE,COVINGTON,LA
# Geocoder failed.
# 1350
# Compiling address
# 1350 CAPE CANAVERAL,FL
# Geocoder failed.
# 1351
# Compiling address
# 1351 CLAY CENTER,KS
# Geocoder failed.
# 1352
# Latitude already there.
# 1353
# Compiling address
# 1353 VIRGINIA BEACH,VA
# Geocoder failed.
# 1354
# Compiling address
# 1354 ENFIELD,CT
# Geocoder failed.
# 1355
# Compiling address
# 1355 LA MARQUE,TX
# Geocoder failed.
# 1356
# Compiling address
# 1356 LAS VEGAS,NV
# Geocoder failed.
# 1357
# Compiling address
# 1357 SODDY DAISY,TN
# Geocoder failed.
# 1358
# Compiling address
# 1358 CLEVELAND,TN
# Geocoder failed.
# 1359
# Compiling address
# 1359 KENNER,LA
# Geocoder failed.
# 1360
# Compiling address
# 1360 ENFIELD,CT
# Geocoder failed.
# 1361
# Compiling address
# 1361 GREENSBORO,NC
# Geocoder failed.
# 1362
# Latitude already there.
# 1363
# Compiling address
# 1363 3109 1ST AVE SOUTH,TEXAS CITY,TX
# Geocoder failed.
# 1364
# Compiling address
# 1364 MARATHON,FL
# Geocoder failed.
# 1365
# Latitude already there.
# 1366
# Compiling address
# 1366 LOVINGTON,NM
# Geocoder failed.
# 1367
# Compiling address
# 1367 BILLERICA,MA
# Geocoder failed.
# 1368
# Compiling address
# 1368 LEBANON,TN
# Geocoder failed.
# 1369
# Compiling address
# 1369 SOUTHWEST CORNER OF MADISON AND HWY 50,JEFFERSON,MO
# Geocoder failed.
# 1370
# Compiling address
# 1370 DENVER CITY,TX
# Geocoder failed.
# 1371
# Compiling address
# 1371 INTERSECTION OF HWY 19 AND NORTH 319 BYPASS,THOMASVILLE,GA
# Geocoder failed.
# 1372
# Compiling address
# 1372 GRAND ISLE AREA COUNTY,LA
# Geocoder failed.
# 1373
# Compiling address
# 1373 WEST POINT,VA
# Geocoder failed.
# 1374
# Compiling address
# 1374 NEW YORK,NY
# Geocoder failed.
# 1375
# Compiling address
# 1375 ST. CROIX,VI
# Geocoder failed.
# 1376
# Latitude already there.
# 1377
# Compiling address
# 1377 INDIANAPOLIS,IN
# Geocoder failed.
# 1378
# Latitude already there.
# 1379
# Compiling address
# 1379 CAPE CANAVERAL,FL
# Geocoder failed.
# 1380
# Compiling address
# 1380 LEXINGTON,KY
# Geocoder failed.
# 1381
# Compiling address
# 1381 MARINA DEL REY,CA
# Geocoder failed.
# 1382
# Compiling address
# 1382 ROSEBURG,OR
# Geocoder failed.
# 1383
# Compiling address
# 1383 WASHINGTON, DC,DC
# Geocoder failed.
# 1384
# Compiling address
# 1384 CAPE GIRARDEAU,MO
# Geocoder failed.
# 1385
# Latitude already there.
# 1386
# Compiling address
# 1386 KANSAS CITY,MO
# Geocoder failed.
# 1387
# Compiling address
# 1387 CHATTANOOGA,TN
# Geocoder failed.
# 1388
# Compiling address
# 1388 SAN DIEGO,CA
# Geocoder failed.
# 1389
# Compiling address
# 1389 JUNEAU,AK
# Geocoder failed.
# 1390
# Compiling address
# 1390 LAFIETTE,LA
# Geocoder failed.
# 1391
# Compiling address
# 1391 SCHUYLKILL HAVEN,PA
# Geocoder failed.
# 1392
# Latitude already there.
# 1393
# Compiling address
# 1393 CHARLESTON,SC
# Geocoder failed.
# 1394
# Compiling address
# 1394 BETWEEN FRANKLIN AVE AND WESTERVELT AVE.,STATEN ISLAND,NY
# Geocoder failed.
# 1395
# Latitude already there.
# 1396
# Compiling address
# 1396 HONOLULU,HI
# Geocoder failed.
# 1397
# Compiling address
# 1397 SEATTLE,WA
# Geocoder failed.
# 1398
# Compiling address
# 1398 PIKETON,OH
# Geocoder failed.
# 1399
# Compiling address
# 1399 NATIONAL CITY,CA
# Geocoder failed.
# 1400
# Compiling address
# 1400 DE SOTO,MO
# Geocoder failed.
# 1401
# Compiling address
# 1401 CAMP PENDLETON,CA
# Geocoder failed.
# 1402
# Compiling address
# 1402 NORTH ADAMS,MA
# Geocoder failed.
# 1403
# Compiling address
# 1403 WARDON,WA
# Geocoder failed.
# 1404
# Compiling address
# 1404 SANTA BARBARA,CA
# Geocoder failed.
# 1405
# Compiling address
# 1405 SAN ANTONIO,TX
# Geocoder failed.
# 1406
# Compiling address
# 1406 9958 LOUISIANA HWY 18,ST. JAMES,LA
# Geocoder failed.
# 1407
# Compiling address
# 1407 3 MI WEST ON U.S. HWY 60,PAMPA,TX
# Geocoder failed.
# 1408
# Compiling address
# 1408 MARTINEZ,CA
# Geocoder failed.
# 1409
# Latitude already there.
# 1410
# Compiling address
# 1410 HACKBERRY,LA
# Geocoder failed.
# 1411
# Latitude already there.
# 1412
# Compiling address
# 1412 GLENDALE,CA
# Geocoder failed.
# 1413
# Latitude already there.
# 1414
# Compiling address
# 1414 PITI,GU
# Geocoder failed.
# 1415
# Compiling address
# 1415 FERNDALE,WA
# Geocoder failed.
# 1416
# Compiling address
# 1416 WEST LAKE,LA
# Geocoder failed.
# 1417
# Compiling address
# 1417 AXIS,AL
# Geocoder failed.
# 1418
# Compiling address
# 1418 210 STATE HWY 59,DOUGLAS,WY
# Geocoder failed.
# 1419
# Compiling address
# 1419 LONGPORT,NJ
# Geocoder failed.
# 1420
# Latitude already there.
# 1421
# Compiling address
# 1421 BAYTOWN,TX
# Geocoder failed.
# 1422
# Compiling address
# 1422 SAN DIEGO,CA
# Geocoder failed.
# 1423
# Compiling address
# 1423 EXETER,CA
# Geocoder failed.
# 1424
# Compiling address
# 1424 CUMBERLAND,MD
# Geocoder failed.
# 1425
# Compiling address
# 1425 STEPHENS COUNTY,OK
# Geocoder failed.
# 1426
# Compiling address
# 1426 SEGUIN,TX
# Geocoder failed.
# 1427
# Compiling address
# 1427 NEWTON,MA
# Geocoder failed.
# 1428
# Compiling address
# 1428 HICKSVILLE,NY
# Geocoder failed.
# 1429
# Latitude already there.
# 1430
# Latitude already there.
# 1431
# Latitude already there.
# 1432
# Compiling address
# 1432 COTTAGE GROVE,OR
# Geocoder failed.
# 1433
# Compiling address
# 1433 CUTT OFF,LA
# Geocoder failed.
# 1434
# Compiling address
# 1434 WEST PALM BEACH,FL
# Geocoder failed.
# 1435
# Compiling address
# 1435 SEATTLE,WA
# Geocoder failed.
# 1436
# Compiling address
# 1436 MARINA DEL REY,CA
# Geocoder failed.
# 1437
# Compiling address
# 1437 HONOLULU,HI
# Geocoder failed.
# 1438
# Compiling address
# 1438 TERMINAL ISLAND,CA
# Geocoder failed.
# 1439
# Compiling address
# 1439 NEWTON,MA
# Geocoder failed.
# 1440
# Compiling address
# 1440 FENTON,MI
# Geocoder failed.
# 1441
# Latitude already there.
# 1442
# Compiling address
# 1442 HOUSTON,TX
# Geocoder failed.
# 1443
# Compiling address
# 1443 HACKBERRY,LA
# Geocoder failed.
# 1444
# Latitude already there.
# 1445
# Compiling address
# 1445 BENBROOK,TX
# Geocoder failed.
# 1446
# Compiling address
# 1446 BAKER CITY,OR
# Geocoder failed.
# 1447
# Latitude already there.
# 1448
# Latitude already there.
# 1449
# Compiling address
# 1449 SAN FRANCISCO,CA
# Geocoder failed.
# 1450
# Compiling address
# 1450 SAN DIEGO,CA
# Geocoder failed.
# 1451
# Compiling address
# 1451 7001 SEAVIEW AVE NW,SEATTLE,WA
# Geocoder failed.
# 1452
# Compiling address
# 1452 INDEPENDENCE,MO
# Geocoder failed.
# 1453
# Compiling address
# 1453 WHITE EARTH,ND
# Geocoder failed.
# 1454
# Compiling address
# 1454 JOHNSON CITY,TN
# Geocoder failed.
# 1455
# Compiling address
# 1455 SAN FRANCISCO,CA
# Geocoder failed.
# 1456
# Compiling address
# 1456 BIRMINGHAM,AL
# Geocoder failed.
# 1457
# Compiling address
# 1457 78 STATE ROUTE 115,OCEAN SHORES,WA
# Geocoder failed.
# 1458
# Latitude already there.
# 1459
# Compiling address
# 1459 KALAELOA OAHU,HI
# Geocoder failed.
# 1460
# Compiling address
# 1460 9959 HIGHWAY 18,ST JAMES,LA
# Geocoder failed.
# 1461
# Latitude already there.
# 1462
# Latitude already there.
# 1463
# Compiling address
# 1463 MANSFIELD,OH
# Geocoder failed.
# 1464
# Compiling address
# 1464 NEW BUFFALO,MI
# Geocoder failed.
# 1465
# Compiling address
# 1465 OTHELLO,WA
# Geocoder failed.
# 1466
# Compiling address
# 1466 LBJ BLVD AND FL EAST COAST RR TRACKS,HOLLY HILL,FL
# Geocoder failed.
# 1467
# Compiling address
# 1467 MILWAUKEE,WI
# Geocoder failed.
# 1468
# Compiling address
# 1468 HOLLY HILL,FL
# Geocoder failed.
# 1469
# Compiling address
# 1469 3120 NORTH POST ROAD AND 8645 EAST 33RD STREET (2 ENTRY POINTS),INDIANAPOLIS,IN
# Geocoder failed.
# 1470
# Compiling address
# 1470 REECE,AL
# Geocoder failed.
# 1471
# Compiling address
# 1471 COLONIAL HEIGHTS,VA
# Geocoder failed.
# 1472
# Compiling address
# 1472 SEATTLE,WA
# Geocoder failed.
# 1473
# Compiling address
# 1473 4127 HWY 361,ENGLESIDE,TX
# Geocoder failed.
# 1474
# Compiling address
# 1474 515 SOUTH HWY 430,ROCK SPRINGS,WY
# Geocoder failed.
# 1475
# Compiling address
# 1475 DUNCOMBE,IA
# Geocoder failed.
# 1476
# Latitude already there.
# 1477
# Compiling address
# 1477 RAYMORE,MO
# Geocoder failed.
# 1478
# Compiling address
# 1478 ALEXANDERIA BAY,NY
# Geocoder failed.
# 1479
# Latitude already there.
# 1480
# Compiling address
# 1480 RAYNOLDSBURG,OH
# Geocoder failed.
# 1481
# Compiling address
# 1481 CLAY CENTER,KS
# Geocoder failed.
# 1482
# Compiling address
# 1482 FORT PIERRE,SD
# Geocoder failed.
# 1483
# Latitude already there.
# 1484
# Compiling address
# 1484 HOUSTON,TX
# Geocoder failed.
# 1485
# Latitude already there.
# 1486
# Compiling address
# 1486 MCCLELLANVILLE,SC
# Geocoder failed.
# 1487
# Compiling address
# 1487 PORT ARTHUR,TX
# Geocoder failed.
# 1488
# Compiling address
# 1488 WILMINGTON,NC
# Geocoder failed.
# 1489
# Compiling address
# 1489 SEATTLE,WA
# Geocoder failed.
# 1490
# Compiling address
# 1490 MARQUETTE,MI
# Geocoder failed.
# 1491
# Compiling address
# 1491 RUFFSDALE,PA
# Geocoder failed.
# 1492
# Compiling address
# 1492 FT LAUDERDALE,FL
# Geocoder failed.
# 1493
# Compiling address
# 1493 CHEYENNE,WY
# Geocoder failed.
# 1494
# Compiling address
# 1494 HARRISON TOWNSHIP,MI
# Geocoder failed.
# 1495
# Compiling address
# 1495 EXETER,CA
# Geocoder failed.
# 1496
# Compiling address
# 1496 GLENDALE,CA
# Geocoder failed.
# 1497
# Compiling address
# 1497 ELKHART,IN
# Geocoder failed.
# 1498
# Compiling address
# 1498 NORTH EAST,PA
# Geocoder failed.
# 1499
# Latitude already there.
# 1500
# Compiling address
# 1500 LAFITTE,LA
# Geocoder failed.
# 1501
# Compiling address
# 1501 MIAMI,FL
# Geocoder failed.
# 1502
# Compiling address
# 1502 LEBANON,TN
# Geocoder failed.
# 1503
# Latitude already there.
# 1504
# Latitude already there.
# 1505
# Compiling address
# 1505 MARCUS HOOK,PA
# Geocoder failed.
# 1506
# Compiling address
# 1506 COOS BAY,OR
# Geocoder failed.
# 1507
# Compiling address
# 1507 38003 FARM ROAD 1379,MIDLAND,TX
# Geocoder failed.
# 1508
# Latitude already there.
# 1509
# Latitude already there.
# 1510
# Compiling address
# 1510 PINE BLUFF,AR
# Geocoder failed.
# 1511
# Latitude already there.
# 1512
# Compiling address
# 1512 NEWPORT BEACH,CA
# Geocoder failed.
# 1513
# Compiling address
# 1513 1/4 MILE EAST OF THE INTERSECTION OF COUNTY ROAD 71 AND HIGHWAY 138,CROOK,CO
# Geocoder failed.
# 1514
# Compiling address
# 1514 DAUPHIN ISLAND,AL
# Geocoder failed.
# 1515
# Compiling address
# 1515 PEKIN,IL
# Geocoder failed.
# 1516
# Compiling address
# 1516 NORCROSS,GA
# Geocoder failed.
# 1517
# Compiling address
# 1517 4127 HWY 361,INGLESIDE,TX
# Geocoder failed.
# 1518
# Compiling address
# 1518 MARQUETTE,MI
# Geocoder failed.
# 1519
# Latitude already there.
# 1520
# Compiling address
# 1520 COUNTRY CLUB HILLS,IL
# Geocoder failed.
# 1521
# Latitude already there.
# 1522
# Compiling address
# 1522 NORTH SMITHFIELD,RI
# Geocoder failed.
# 1523
# Compiling address
# 1523 CORPUS CHRISTI,TX
# Geocoder failed.
# 1524
# Latitude already there.
# 1525
# Latitude already there.
# 1526
# Compiling address
# 1526 ROCHESTER,IN
# Geocoder failed.
# 1527
# Latitude already there.
# 1528
# Compiling address
# 1528 CONCRETE,WA
# Geocoder failed.
# 1529
# Latitude already there.
# 1530
# Compiling address
# 1530 ALLENTOWN,PA
# Geocoder failed.
# 1531
# Compiling address
# 1531 COLLINS,MS
# Geocoder failed.
# 1532
# Compiling address
# 1532 BECKER,NM
# Geocoder failed.
# 1533
# Compiling address
# 1533 NOVATO,CA
# Geocoder failed.
# 1534
# Compiling address
# 1534 SITKA,AK
# Geocoder failed.
# 1535
# Compiling address
# 1535 PICKFAW,LA
# Geocoder failed.
# 1536
# Compiling address
# 1536 ELKHART,IN
# Geocoder failed.
# 1537
# Compiling address
# 1537 NORCO,LA
# Geocoder failed.
# 1538
# Latitude already there.
# 1539
# Latitude already there.
# 1540
# Compiling address
# 1540 MERRITT ISLAND,FL
# Geocoder failed.
# 1541
# Compiling address
# 1541 ARVADA,CO
# Geocoder failed.
# 1542
# Compiling address
# 1542 SITKA,AK
# Geocoder failed.
# 1543
# Compiling address
# 1543 NEAH BAY,WA
# Geocoder failed.
# 1544
# Latitude already there.
# 1545
# Compiling address
# 1545 ESCONDIDO,CA
# Geocoder failed.
# 1546
# Latitude already there.
# 1547
# Compiling address
# 1547 SARASOTA,FL
# Geocoder failed.
# 1548
# Compiling address
# 1548 BAKER,CA
# Geocoder failed.
# 1549
# Compiling address
# 1549 SAN DIEGO,CA
# Geocoder failed.
# 1550
# Compiling address
# 1550 MARTINEZ,CA
# Geocoder failed.
# 1551
# Compiling address
# 1551 LOS ANGELES,CA
# Geocoder failed.
# 1552
# Compiling address
# 1552 LAPORTE,TX
# Geocoder failed.
# 1553
# Compiling address
# 1553 KODIAK,AK
# Geocoder failed.
# 1554
# Compiling address
# 1554 WEVER,IA
# Geocoder failed.
# 1555
# Compiling address
# 1555 EDDYVILLE,IA
# Geocoder failed.
# 1556
# Compiling address
# 1556 LOUISVILLE,KY
# Geocoder failed.
# 1557
# Compiling address
# 1557 BAKER,CA
# Geocoder failed.
# 1558
# Compiling address
# 1558 MALLORY ROAD GRADE CROSSING,UNION CITY,GA

# %%
print('Preparing to merge')

geo = geo.merge(locations,how='left',on='SEQNOS')

# Create a text file noting record ID of where we left off with the last import of data.
biggest = geo.SEQNOS.max()
bookmark = pd.DataFrame({'top':[biggest]})
bookmark.to_csv('bookmark')

# Clean up latitudes and longitudes to proper sign based on hemisphere
geo.new_latitude[(geo.new_latquad == 'N')|geo.new_latquad.isnull()] = abs(geo.new_latitude)
geo.new_latitude[geo.new_latquad == 'S'] = -1 * abs(geo.new_latitude)
geo.new_longitude[geo.new_longquad == 'E'] = abs(geo.new_longitude)
geo.new_longitude[(geo.new_longquad == 'W')|geo.new_longquad.isnull()] = -1 * abs(geo.new_longitude)

# Create a geodataframe by converting coordinate data to Point objects
from shapely.geometry import Point
geometry = [Point(xy) for xy in zip(geo.new_longitude, geo.new_latitude)]
points   = geopandas.GeoDataFrame(geometry, geometry=geometry)

# Boolean to specify records to update using the coordinate data
null_coordinates = geo.geometry.isnull()
#null_coordinates = geo.new_latitude.notnull()

# Update the geometry with data from the latitude and longitude coordinates
geo.loc[null_coordinates,'geometry'] = points

# DEPRECATED -- dump to geojson
# Output everything as a text file for use elswhere
#jsonfile = 'spillcalls' + now + '.geojson'
#geo.to_file(jsonfile, driver='GeoJSON')

# Redo geodataframe as a regular dataframe
export = pd.DataFrame(geo)
# Export bulk file or update file
if appending:
	export.to_csv('latest_spillcalls.csv',encoding='utf-8')
else:
	export.to_csv('spillcalls-all.csv',encoding='utf-8')

# Finished
